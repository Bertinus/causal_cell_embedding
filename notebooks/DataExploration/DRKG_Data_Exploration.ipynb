# %%
import pandas as pd
import numpy as np
drkg_file = '../data/drkg/drkg.tsv'
df = pd.read_csv(drkg_file, sep="\t", header=None)
import pickle
import os
import rdkit
from rdkit import Chem
from rdkit.Chem import DataStructs
from rdkit.Chem.rdMolDescriptors import GetMorganFingerprintAsBitVect
from rdkit.Chem.Fingerprints import FingerprintMols
from rdkit.Chem import rdMolHash
from tqdm import tqdm
# Out:
# RDKit WARNING: [14:36:06] Enabling RDKit 2019.09.3 jupyter extensions

# %%
df
# Out:
#                    0                               1            2
# 0         Gene::2157  bioarx::HumGenHumGen:Gene:Gene   Gene::2157
# 1         Gene::2157  bioarx::HumGenHumGen:Gene:Gene   Gene::5264
# 2         Gene::2157  bioarx::HumGenHumGen:Gene:Gene   Gene::2158
# 3         Gene::2157  bioarx::HumGenHumGen:Gene:Gene   Gene::3309
# 4         Gene::2157  bioarx::HumGenHumGen:Gene:Gene  Gene::28912
# ...              ...                             ...          ...
# 5874256  Gene::29099     STRING::REACTION::Gene:Gene   Gene::1643
# 5874257  Gene::51645     STRING::REACTION::Gene:Gene   Gene::3183
# 5874258    Gene::865    STRING::CATALYSIS::Gene:Gene    Gene::983
# 5874259   Gene::1066      STRING::BINDING::Gene:Gene   Gene::7365
# 5874260   Gene::6118      STRING::BINDING::Gene:Gene   Gene::1111
#
# [5874261 rows x 3 columns]

# %%
all_nodes = np.unique(np.concatenate((df[0].values, df[2].values)))

# %%
len(all_nodes)
# Out:
# 97238

# %%
string = df[df[1].apply(lambda s: s[:6] == 'STRING')]

# %%
all_string_nodes = np.unique(np.concatenate((string[0].values, string[2].values)))

# %%
all_string_nodes
# Out:
# array(['Gene::1', 'Gene::10', 'Gene::100', ..., 'Gene::9993',
#        'Gene::9994', 'Gene::9997'], dtype=object)

# %%
string_gene_ids = [s[6:] for s in all_string_nodes]

# %%
len(string_gene_ids)
# Out:
# 18316

# %%
string_gene_ids[:20]
# Out:
# ['1',
#  '10',
#  '100',
#  '1000',
#  '10000',
#  '100008586',
#  '10001',
#  '10002',
#  '10003',
#  '100037417',
#  '100038246',
#  '10004',
#  '100049587',
#  '10005',
#  '10006',
#  '10007',
#  '10008',
#  '10009',
#  '1001',
#  '10010']

# %% [markdown]
# ## Comparing with landmark genes

# %%
# Get list of landmark genes
gene_info = pd.read_csv('../Data/L1000_PhaseI/GSE92742_Broad_LINCS/GSE92742_Broad_LINCS_gene_info.txt', sep="\t")
landmark_gene_list = list(gene_info[gene_info['pr_is_lm'] == 1]["pr_gene_id"].astype(str))

# %%
len(landmark_gene_list)
# Out:
# 978

# %%
len(set(landmark_gene_list).intersection(set(string_gene_ids)))
# Out:
# 972

# %% [markdown]
# ## Drug ids

# %%
df[1].unique()
# Out:
# array(['bioarx::HumGenHumGen:Gene:Gene', 'bioarx::VirGenHumGen:Gene:Gene',
#        'bioarx::DrugVirGen:Compound:Gene',
#        'bioarx::DrugHumGen:Compound:Gene',
#        'bioarx::Covid2_acc_host_gene::Disease:Gene',
#        'bioarx::Coronavirus_ass_host_gene::Disease:Gene',
#        'DGIDB::INHIBITOR::Gene:Compound',
#        'DGIDB::ANTAGONIST::Gene:Compound', 'DGIDB::OTHER::Gene:Compound',
#        'DGIDB::AGONIST::Gene:Compound', 'DGIDB::BINDER::Gene:Compound',
#        'DGIDB::MODULATOR::Gene:Compound', 'DGIDB::BLOCKER::Gene:Compound',
#        'DGIDB::CHANNEL BLOCKER::Gene:Compound',
#        'DGIDB::ANTIBODY::Gene:Compound',
#        'DGIDB::POSITIVE ALLOSTERIC MODULATOR::Gene:Compound',
#        'DGIDB::ALLOSTERIC MODULATOR::Gene:Compound',
#        'DGIDB::ACTIVATOR::Gene:Compound',
#        'DGIDB::PARTIAL AGONIST::Gene:Compound',
#        'DRUGBANK::x-atc::Compound:Atc',
#        'DRUGBANK::ddi-interactor-in::Compound:Compound',
#        'DRUGBANK::target::Compound:Gene',
#        'DRUGBANK::enzyme::Compound:Gene',
#        'DRUGBANK::carrier::Compound:Gene',
#        'DRUGBANK::treats::Compound:Disease', 'GNBR::E::Compound:Gene',
#        'GNBR::A+::Compound:Gene', 'GNBR::N::Compound:Gene',
#        'GNBR::K::Compound:Gene', 'GNBR::A-::Compound:Gene',
#        'GNBR::E+::Compound:Gene', 'GNBR::B::Compound:Gene',
#        'GNBR::E-::Compound:Gene', 'GNBR::O::Compound:Gene',
#        'GNBR::Z::Compound:Gene', 'GNBR::T::Compound:Disease',
#        'GNBR::C::Compound:Disease', 'GNBR::Sa::Compound:Disease',
#        'GNBR::Pa::Compound:Disease', 'GNBR::Mp::Compound:Disease',
#        'GNBR::Pr::Compound:Disease', 'GNBR::J::Compound:Disease',
#        'GNBR::L::Gene:Disease', 'GNBR::U::Gene:Disease',
#        'GNBR::Y::Gene:Disease', 'GNBR::J::Gene:Disease',
#        'GNBR::Te::Gene:Disease', 'GNBR::Md::Gene:Disease',
#        'GNBR::G::Gene:Disease', 'GNBR::D::Gene:Disease',
#        'GNBR::X::Gene:Disease', 'GNBR::Ud::Gene:Disease',
#        'GNBR::V+::Gene:Gene', 'GNBR::Q::Gene:Gene', 'GNBR::Rg::Gene:Gene',
#        'GNBR::B::Gene:Gene', 'GNBR::I::Gene:Gene', 'GNBR::E+::Gene:Gene',
#        'GNBR::H::Gene:Gene', 'GNBR::W::Gene:Gene', 'GNBR::E::Gene:Gene',
#        'GNBR::in_tax::Gene:Tax',
#        'Hetionet::GpBP::Gene:Biological Process',
#        'Hetionet::GiG::Gene:Gene', 'Hetionet::CrC::Compound:Compound',
#        'Hetionet::DdG::Disease:Gene', 'Hetionet::DpS::Disease:Symptom',
#        'Hetionet::DlA::Disease:Anatomy',
#        'Hetionet::CtD::Compound:Disease', 'Hetionet::CbG::Compound:Gene',
#        'Hetionet::CuG::Compound:Gene', 'Hetionet::DrD::Disease:Disease',
#        'Hetionet::DaG::Disease:Gene', 'Hetionet::CpD::Compound:Disease',
#        'Hetionet::AdG::Anatomy:Gene', 'Hetionet::AuG::Anatomy:Gene',
#        'Hetionet::GcG::Gene:Gene',
#        'Hetionet::GpMF::Gene:Molecular Function',
#        'Hetionet::PCiC::Pharmacologic Class:Compound',
#        'Hetionet::GpCC::Gene:Cellular Component',
#        'Hetionet::Gr>G::Gene:Gene', 'Hetionet::CdG::Compound:Gene',
#        'Hetionet::DuG::Disease:Gene', 'Hetionet::GpPW::Gene:Pathway',
#        'Hetionet::CcSE::Compound:Side Effect',
#        'Hetionet::AeG::Anatomy:Gene',
#        'INTACT::PHYSICAL ASSOCIATION::Compound:Gene',
#        'INTACT::DIRECT INTERACTION::Compound:Gene',
#        'INTACT::ASSOCIATION::Compound:Gene',
#        'INTACT::ASSOCIATION::Gene:Gene',
#        'INTACT::PHYSICAL ASSOCIATION::Gene:Gene',
#        'INTACT::COLOCALIZATION::Gene:Gene',
#        'INTACT::DEPHOSPHORYLATION REACTION::Gene:Gene',
#        'INTACT::CLEAVAGE REACTION::Gene:Gene',
#        'INTACT::DIRECT INTERACTION::Gene:Gene',
#        'INTACT::PHOSPHORYLATION REACTION::Gene:Gene',
#        'INTACT::ADP RIBOSYLATION REACTION::Gene:Gene',
#        'INTACT::UBIQUITINATION REACTION::Gene:Gene',
#        'INTACT::PROTEIN CLEAVAGE::Gene:Gene',
#        'STRING::REACTION::Gene:Gene', 'STRING::CATALYSIS::Gene:Gene',
#        'STRING::ACTIVATION::Gene:Gene', 'STRING::INHIBITION::Gene:Gene',
#        'STRING::OTHER::Gene:Gene', 'STRING::BINDING::Gene:Gene',
#        'STRING::PTMOD::Gene:Gene', 'STRING::EXPRESSION::Gene:Gene'],
#       dtype=object)

# %%
df[df[1].apply(lambda s: s[:8] == 'DRUGBANK')]
# Out:
#                          0                                               1  \
# 111046   Compound::DB00001                   DRUGBANK::x-atc::Compound:Atc
# 111047   Compound::DB00001  DRUGBANK::ddi-interactor-in::Compound:Compound
# 111048   Compound::DB00001  DRUGBANK::ddi-interactor-in::Compound:Compound
# 111049   Compound::DB00001  DRUGBANK::ddi-interactor-in::Compound:Compound
# 111050   Compound::DB00001  DRUGBANK::ddi-interactor-in::Compound:Compound
# ...                    ...                                             ...
# 1535831  Compound::DB15578                   DRUGBANK::x-atc::Compound:Atc
# 1535832  Compound::DB15598                   DRUGBANK::x-atc::Compound:Atc
# 1535833  Compound::DB15598                   DRUGBANK::x-atc::Compound:Atc
# 1535834  Compound::DB15598                   DRUGBANK::x-atc::Compound:Atc
# 1535835  Compound::DB15598                   DRUGBANK::x-atc::Compound:Atc
#
#                          2
# 111046        Atc::B01AE02
# 111047   Compound::DB06605
# 111048   Compound::DB06695
# 111049   Compound::DB01254
# 111050   Compound::DB01609
# ...                    ...
# 1535831             Atc::G
# 1535832         Atc::B03AB
# 1535833          Atc::B03A
# 1535834           Atc::B03
# 1535835             Atc::B
#
# [1424790 rows x 3 columns]

# %%
drugbank_smiles = pd.read_csv('../Data/DRKG/drugbank_info/drugbank_smiles.txt', sep='\t', header=None)

# %%
drugbank_smiles = drugbank_smiles[1].unique()

# %%
len(drugbank_smiles)
# Out:
# 8830

# %%
 pd.read_csv("../Data/L1000_PhaseI/GSE92742_Broad_LINCS/GSE92742_Broad_LINCS_pert_info.txt", sep="\t",
                        index_col="pert_id")
# Out:
#                     pert_iname   pert_type  is_touchstone inchi_key_prefix  \
# pert_id
# 56582                     AKT2      trt_oe              0             -666
# 5981                      HSF1      trt_oe              0             -666
# 7150                    NFE2L2      trt_oe              0             -666
# ABL1_G2A                  ABL1  trt_oe.mut              0             -666
# ABL1_T315I                ABL1  trt_oe.mut              0             -666
# ...                        ...         ...            ...              ...
# ccsbBroad304_99991  LUCIFERASE  ctl_vector              0             -666
# ccsbBroad304_99994        lacZ  ctl_vector              0             -666
# ccsbBroad304_99997        eGFP  ctl_vector              0             -666
# dsRED                    DSRED      trt_oe              0             -666
# renilla                RENILLA      trt_oe              0             -666
#
#                    inchi_key canonical_smiles pubchem_cid
# pert_id
# 56582                   -666             -666        -666
# 5981                    -666             -666        -666
# 7150                    -666             -666        -666
# ABL1_G2A                -666             -666        -666
# ABL1_T315I              -666             -666        -666
# ...                      ...              ...         ...
# ccsbBroad304_99991      -666             -666        -666
# ccsbBroad304_99994      -666             -666        -666
# ccsbBroad304_99997      -666             -666        -666
# dsRED                   -666             -666        -666
# renilla                 -666             -666        -666
#
# [51383 rows x 7 columns]

# %%
pert_info_1 = pd.read_csv("../Data/L1000_PhaseI/GSE92742_Broad_LINCS/GSE92742_Broad_LINCS_pert_info.txt", sep="\t",
                        index_col="pert_id", usecols=["pert_id", "pert_iname", "canonical_smiles"])
pert_info_2 = pd.read_csv("../Data/L1000_PhaseII/GSE70138_Broad_LINCS/pert_info_2017-03-06.txt", sep="\t",
                          index_col="pert_id", usecols=["pert_id", "pert_iname", "canonical_smiles"])
pert_info = pd.concat([pert_info_1, pert_info_2], sort=False)

# %%
pert_info
# Out:
#                 pert_iname canonical_smiles
# pert_id
# 56582                 AKT2             -666
# 5981                  HSF1             -666
# 7150                NFE2L2             -666
# ABL1_G2A              ABL1             -666
# ABL1_T315I            ABL1             -666
# ...                    ...              ...
# BRDN0000585417        LACZ             -666
# BRDN0000562990        EGFP             -666
# BRDN0000585533  LUCIFERASE             -666
# BRDN0000563287        EGFP             -666
# BRDN0000562919        EGFP             -666
#
# [53553 rows x 2 columns]

# %%
l1000_smiles = pert_info['canonical_smiles'].unique()

# %%
len(l1000_smiles)
# Out:
# 21213

# %%
len(set(drugbank_smiles).intersection(set(l1000_smiles)))
# Out:
# 104

# %%
pickle_in = open('../Data/L1000_PhaseI/dataframe.pkl', "rb")
data = pickle.load(pickle_in)

# %%
data
# Out:
#                                                                                      gene_expr
# cid
# CPC005_A375_6H:BRD-A85280935-003-01-7:10     [-0.6806448, -0.52947366, -0.4659655, -1.73020...
# CPC005_A375_6H:BRD-A07824748-001-02-6:10     [1.8314098, -0.75270295, 0.8809619, -0.2224250...
# CPC004_A375_6H:BRD-K20482099-001-01-1:10     [3.9644134, 3.3888953, -1.7222486, -0.30714303...
# CPC005_A375_6H:BRD-K62929068-001-03-3:10     [1.5089136, 0.64932656, -0.6492754, -0.0263244...
# CPC005_A375_6H:BRD-K43405658-001-01-8:10     [0.8581516, -0.7991509, 0.13817382, -1.2157025...
# ...                                                                                        ...
# PCLB003_PC3_24H:BRD-A75409952-001-01-6:0.12  [-0.64300364, -0.9303427, -0.48076797, 0.33226...
# PCLB003_PC3_24H:BRD-A75409952-001-01-6:0.04  [0.48386264, -1.1165136, -0.4914876, 0.2097616...
# PCLB003_PC3_24H:BRD-K42573370-001-01-1:10    [-1.8989, 2.9124, 0.0918, 3.4367, 1.5604, -4.1...
# PCLB003_PC3_24H:BRD-K53665955-001-01-4:0.04  [-1.602, 1.8905001, -1.5856501, -0.5667, -0.52...
# PCLB003_PC3_24H:BRD-K04466929-001-05-1:10    [-6.9124, 10.0, -5.6362, 2.1595, 2.2654, 1.254...
#
# [217330 rows x 1 columns]

# %%
dict_id_to_name = np.load('../Data/DRKG/dict_id_to_name.npy', allow_pickle=True).item()

# %%
all_names = []
for value in dict_id_to_name.values():
    all_names.extend(value)

# %%
len(all_names)
# Out:
# 33168

# %%
pert_info['pert_iname'].values
# Out:
# array(['AKT2', 'HSF1', 'NFE2L2', ..., 'LUCIFERASE', 'EGFP', 'EGFP'],
#       dtype=object)

# %%
all_names
# Out:
# ['Lepirudin',
#  'Hirudin variant-1',
#  'Lepirudin recombinant',
#  'DB00001',
#  'Cetuximab',
#  'DB00002',
#  'Dornase alfa',
#  'Deoxyribonuclease (human clone 18-1 protein moiety)',
#  'Dornase alfa, recombinant',
#  'Dornase alpha',
#  'Recombinant deoxyribonuclease (DNAse)',
#  'DB00003',
#  'Denileukin diftitox',
#  'Denileukin',
#  'Interleukin-2/diptheria toxin fusion protein',
#  'DB00004',
#  'Etanercept',
#  'etanercept-szzs',
#  'etanercept-ykro',
#  'Recombinant human TNF',
#  'rhu TNFR:Fc',
#  'rhu-TNFR:Fc',
#  'TNFR-Immunoadhesin',
#  'DB00005',
#  'Peginterferon alfa-2a',
#  'PEG-IFN alfa-2A',
#  'PEG-Interferon alfa-2A',
#  'Pegylated Interfeaon alfa-2A',
#  'Pegylated interferon alfa-2a',
#  'Pegylated interferon alpha-2a',
#  'Pegylated-interferon alfa 2a',
#  'DB00008',
#  'Alteplase',
#  'Alteplase (genetical recombination)',
#  'Alteplase, recombinant',
#  'Alteplase,recombinant',
#  'Plasminogen activator (human tissue-type protein moiety)',
#  'rt-PA',
#  't-PA',
#  't-plasminogen activator',
#  'Tissue plasminogen activator',
#  'Tissue plasminogen activator alteplase',
#  'Tissue plasminogen activator, recombinant',
#  'tPA',
#  'DB00009',
#  'Sermorelin',
#  'DB00010',
#  'Interferon alfa-n1',
#  'Interferon alpha-n1 (INS)',
#  'DB00011',
#  'Darbepoetin alfa',
#  'Darbepoetin',
#  'Darbepoetin alfa,recombinant',
#  'DB00012',
#  'Urokinase',
#  'Kinase (enzyme-activating), uro-urokinase',
#  'TCUK',
#  'Tissue culture urokinase',
#  'Two-chain urokinase',
#  'DB00013',
#  'Reteplase',
#  'Human t-PA (residues 1-3 and 176-527)',
#  'Reteplase, recombinant',
#  'Reteplase,recombinant',
#  'DB00015',
#  'Erythropoietin',
#  'E.P.O.',
#  'Epoetin alfa',
#  'Epoetin alfa rDNA',
#  'Epoetin alfa-epbx',
#  'Epoetin alfa, recombinant',
#  'Epoetin beta',
#  'Epoetin beta rDNA',
#  'Epoetin epsilon',
#  'Epoetin gamma',
#  'Epoetin gamma rDNA',
#  'Epoetin kappa',
#  'Epoetin omega',
#  'Epoetin theta',
#  'Epoetin zeta',
#  'Erythropoiesis stimulating factor',
#  'Erythropoietin (human, recombinant)',
#  'Erythropoietin (recombinant human)',
#  'ESF',
#  'SH-polypeptide-72',
#  'DB00016',
#  'Salmon calcitonin',
#  'Calcitonin (Salmon Synthetic)',
#  'Calcitonin salmon',
#  'Calcitonin salmon recombinant',
#  'Calcitonin-salmon',
#  'Calcitonin, salmon',
#  'Recombinant salmon calcitonin',
#  'DB00017',
#  'Interferon alfa-n3',
#  'DB00018',
#  'Pegfilgrastim',
#  'Granulocyte colony-stimulating factor pegfilgrastim',
#  'peg-filgrastim',
#  'pegfilgrastim-bmez',
#  'pegfilgrastim-cbqv',
#  'pegfilgrastim-jmdb',
#  'DB00019',
#  'Sargramostim',
#  'Recombinant human granulocyte-macrophage colony stimulating factor',
#  'rGM-CSF',
#  'rHu GM-CSF',
#  'DB00020',
#  'Peginterferon alfa-2b',
#  'DB00022',
#  'Asparaginase Escherichia coli',
#  'Asparaginase',
#  'Asparaginase (E. coli)',
#  'Colaspase',
#  'Escherichia coli L-asparaginase',
#  'L-asparaginase',
#  'L-asparagine amidohydrolase',
#  'DB00023',
#  'Thyrotropin alfa',
#  'Recombinant Human Thyroid Stimulating Hormone',
#  'Recombinant thyrotropin alfa',
#  'rhTSH',
#  'rTSH',
#  'Thyrotropin alpha',
#  'DB00024',
#  'Antihemophilic factor, human recombinant',
#  'Antihemophilic factor (recombinant)',
#  'Antihemophilic factor recombinant',
#  'Antihemophilic factor, recombinant',
#  'Factor VIII (rDNA)',
#  'Factor VIII (Recombinant)',
#  'Factor VIII recombin',
#  'Factor VIII, recombinant',
#  'Human Factor VIII (Recombinant)',
#  'Human factor VIII recombinant',
#  'Octocog alfa',
#  'rAHF',
#  'Recombinant antihemophilic factor VIII',
#  'DB00025',
#  'Anakinra',
#  'IL-1RA',
#  'Interleukin-1 receptor antagonist anakinra',
#  'DB00026',
#  'Human immunoglobulin G',
#  'Human IGG',
#  'Human normal immunoglobulin',
#  'Immune globulin (human)',
#  'Immune globulin human',
#  'Immunoglobulin (human)',
#  'Immunoglobulin G (human)',
#  'Immunoglobulin G, human',
#  'IVIg',
#  'DB00028',
#  'Anistreplase',
#  'Anisoylated plasminogen streptokinase activator complex',
#  'APSAC',
#  'DB00029',
#  'Insulin human',
#  'High molecular weight insulin human',
#  'Human insulin',
#  'human insulin (rDNA)',
#  'Insulin (human)',
#  'Insulin human [rDNA origin]',
#  'Insulin Human Regular',
#  'Insulin human regular (rDNA)',
#  'Insulin human, rDNA origin',
#  'Insulin recombinant human',
#  'Insulin recombinant purified human',
#  'Insulin regular',
#  'Insulin, human',
#  'Regular Insulin, human',
#  'DB00030',
#  'Tenecteplase',
#  'TNK-tPA',
#  'DB00031',
#  'Menotropins',
#  'Human menopausal gonadotrophin',
#  'Menotrophin',
#  'Menotropin',
#  'Menotropins (FSH;LH)',
#  'DB00032',
#  'Interferon gamma-1b',
#  'IFN-gamma 1b',
#  'IFN-gamma-1b',
#  'Interferon gamma 1-b',
#  'Interferon gamma-1b, recombinant',
#  'Interferon gamma-2a',
#  'DB00033',
#  'Interferon alfa-2a, Recombinant',
#  'Interferon alfa-2a',
#  'Interferon alfa-2a (recombinant)',
#  'Interferon alfa-2a,recombinant',
#  'Interferon alpha-2a',
#  'Interferon-alfa-2a',
#  'Recombinant human interferon alfa-2a',
#  'Recombinant human interferon-alfa-2a',
#  'rIFN-alpha-2a',
#  'SH-polypeptide-46',
#  'DB00034',
#  'Coagulation factor VIIa Recombinant Human',
#  'Coagulation factor VIIa',
#  'Coagulation factor VIIa (recombinant)',
#  'Eptacog alfa',
#  'Eptacog alfa (activated)',
#  'rFVIIa',
#  'DB00036',
#  'Oprelvekin',
#  'IL-11',
#  'Interleukin 11',
#  'Interleukin-11',
#  'Recombinant interleukin-11',
#  'DB00038',
#  'Palifermin',
#  '24-163 fibroblast growth factor 7 (human)',
#  'DB00039',
#  'Glucagon',
#  'Glucagon (recombinant dna origin)',
#  'Glucagon recombinant',
#  'Glucagon, human',
#  'Glucagon, porcine',
#  'Glucagone',
#  'DB00040',
#  'Aldesleukin',
#  '125-L-serine-2-133-interleukin 2 (human reduced)',
#  'Interleukin-2 aldesleukin',
#  'Interleukin-2(2-133),125-ser',
#  'Recombinant interleukin-2 human',
#  'DB00041',
#  'Botulinum Toxin Type B',
#  'Botulin B',
#  'Botulinum B toxin',
#  'Botulinum neurotoxin type B precursor',
#  'BTX-B',
#  'RimabotulinumtoxinB',
#  'DB00042',
#  'Omalizumab',
#  'DB00043',
#  'Lutropin alfa',
#  'Lutropin alpha',
#  'DB00044',
#  'Lyme disease vaccine (recombinant OspA)',
#  'Lipoprotein OspA antigen recombinant',
#  'Lipoprotein outer surface a borrelia burgdorferi antigen',
#  'OspA lipoprotein',
#  'DB00045',
#  'Insulin lispro',
#  'Insulin lispro (genetical recombination)',
#  'Insulin lispro (rDNA origin)',
#  'Insulin lispro protamine',
#  'Insulin lispro protamine recombinant',
#  'Insulin lispro recombinant',
#  'Insulin,lispro,human/rDNA',
#  'Insulin,lispro,protamine/rDNA',
#  'DB00046',
#  'Insulin glargine',
#  'Insulin Glargine (rDNA origin)',
#  'Insulin glargine recombinant',
#  'DB00047',
#  'Collagenase clostridium histolyticum',
#  'Clostridium histolyticum enzymes',
#  'Collagenase',
#  'DB00048',
#  'Rasburicase',
#  'Urate oxidase',
#  'DB00049',
#  'Adalimumab',
#  'Adalimumab (genetical recombination)',
#  'adalimumab-adaz',
#  'adalimumab-adbm',
#  'adalimumab-afzb',
#  'adalimumab-atto',
#  'adalimumab-bwwd',
#  'DB00051',
#  'Somatotropin',
#  'Growth hormone',
#  'Growth hormone (human)',
#  'hGH',
#  'Human growth hormone',
#  'Recombinant human growth hormone',
#  'rhGH',
#  'Somatotropin (human)',
#  'Somatotropin human',
#  'Somatotropin human growth hormone',
#  'Somatropin',
#  'Somatropin (rDNA origin)',
#  'Somatropin (recombinant DNA origin)',
#  'Somatropin [rDNA origin]',
#  'Somatropin recombinant',
#  'Somatropin(recombinant DNA origin)',
#  'DB00052',
#  'Imiglucerase',
#  'DB00053',
#  'Abciximab',
#  'Abciximab (genetical recombination)',
#  'c7E3',
#  'DB00054',
#  'Drotrecogin alfa',
#  'Activated protein C',
#  'Blood coagulation factor XIV (human)',
#  'Drotrecogin alfa (activated)',
#  'Drotrecogin alfa (activated), lyophilized',
#  'Drotrecogin alfa activated',
#  'Drotrecogin alfa, activated',
#  'Drotrecogin-alfa',
#  'Recombinant human activated protein C (rH-APC)',
#  'DB00055',
#  'Gemtuzumab ozogamicin',
#  'DB00056',
#  'Indium In-111 satumomab pendetide',
#  'Indium (111In) satumomab pendetide',
#  'Indium In 111 satumomab pendetide',
#  'Indium-111 satumomab pendetide',
#  'DB00057',
#  'Alpha-1-proteinase inhibitor',
#  'Alfa 1-proteinase inhibitor (human)',
#  'Alfa1 antitrypsin',
#  'Alpha 1-antitrypsin',
#  'Alpha 1-Proteinase Inhibitor',
#  'Alpha 1-proteinase inhibitor (human)',
#  'Alpha 1-proteinase inhibitor, human',
#  'Alpha-1 protease inhibitor',
#  'Alpha-1 proteinase inhibitor (human)',
#  'Alpha-1-antiproteinase',
#  'Alpha-1-antitrypsin',
#  'Alpha-1-proteinase Inhibitor (human)',
#  'Alpha-1-proteinase inhibitor human',
#  'Alpha-1-proteinase Inhibitor, Human',
#  'Alpha-1-proteinase inhibitor,human',
#  'Alpha1-proteinase Inhibitor',
#  'Alpha1-proteinase inhibitor (human)',
#  'alpha1-proteinase inhibitor human',
#  'API',
#  'DB00058',
#  'Pegaspargase',
#  'Peg-asparaginase',
#  'Peg/L-asparaginase',
#  'DB00059',
#  'Interferon beta-1a',
#  'Interferon beta 1-a',
#  'Interferon beta 1a',
#  'Interferon beta-1a (recombinant human)',
#  'Interferon beta-1a,recombinant',
#  'Interferon-beta-1a',
#  'DB00060',
#  'Pegademase',
#  '(monomethoxypolyethylene glycol succinimidyl) 11-17-adenosine deaminase',
#  'PEG-adenosine deaminase',
#  'pegADA',
#  'Pegademase bovine',
#  'DB00061',
#  'Albumin human',
#  'Albumin (human)',
#  'Albumin, blood',
#  'Albumin, human',
#  'Albumin, human-kjda',
#  'Human albumin',
#  'Human serum albumin',
#  'Serum albumin',
#  'DB00062',
#  'Eptifibatide',
#  'Integrelin',
#  'Intrifiban',
#  'DB00063',
#  'Infliximab',
#  'Infliximab (genetical recombination)',
#  'Infliximab-abda',
#  'Infliximab-axxq',
#  'Infliximab-dyyb',
#  'Infliximab-qbtx',
#  'DB00065',
#  'Follitropin',
#  'Follicle stimulating hormone',
#  'Follitrophin alfa',
#  'Follitrophin alpha',
#  'Follitrophin beta',
#  'Follitropin alfa',
#  'Follitropin alfa/beta',
#  'Follitropin alpha',
#  'Follitropin beta',
#  'Follitropin delta',
#  'Follitropin gamma',
#  'Follotropin recombinant',
#  'FSH',
#  'FSH alpha',
#  'FSH-a',
#  'FSH-b',
#  'FSH-beta',
#  'Recombinant human follicle stimulating hormone beta',
#  'Recombinant human follicle-stimulating hormone (r-HFSH)',
#  'rFSH-alpha',
#  'DB00066',
#  'Interferon beta-1b',
#  'Interferon beta 1b (recombinant)',
#  'Interferon beta-1b,recombinant',
#  'Interferon-beta-1b',
#  'Recombinant interferon beta-1b',
#  'DB00068',
#  'Interferon alfacon-1',
#  'IFN Alfacon-1',
#  'IFN-Con1',
#  'DB00069',
#  'Hyaluronidase (ovine)',
#  'Hyaluronidase (glycoprotein, sheep testis isoenzyme)',
#  'Hyaluronidase (sheep testis isoenzyme)',
#  'Hyaluronidase, ovine',
#  'Ovine hyaluronidase',
#  'DB00070',
#  'Insulin pork',
#  'Insulin (pork)',
#  'Insulin porcine',
#  'Insulin purified porcine',
#  'Insulin purified pork',
#  'Insulin, porcine',
#  'Insulin, regular, pork',
#  'Porcine insulin',
#  'DB00071',
#  'Trastuzumab',
#  'RHUMAB HER2',
#  'trastuzumab-anns',
#  'trastuzumab-dkst',
#  'trastuzumab-dttb',
#  'trastuzumab-pkrb',
#  'trastuzumab-qyyp',
#  'DB00072',
#  'Rituximab',
#  'rituximab-abbs',
#  'rituximab-pvvr',
#  'DB00073',
#  'Basiliximab',
#  'DB00074',
#  'Muromonab',
#  'Anti-CD3',
#  'Muromonab-CD3',
#  'DB00075',
#  'Digoxin Immune Fab (Ovine)',
#  'Digitalis antitoxin',
#  'Digoxin Immune Fab, Ovine',
#  'Digoxin-specific Antibody Fragments',
#  'Ovine digoxin immune fab',
#  'DB00076',
#  'Ibritumomab tiuxetan',
#  'Ibritumomab',
#  'mAb Murine (IGG1) Anti P19437 (CD20_MOUSE)',
#  'DB00078',
#  'Tositumomab',
#  'DB00081',
#  'Pegvisomant',
#  'DB00082',
#  'Botulinum toxin type A',
#  'AbobotulinumtoxinA',
#  'Botulinum A neurotoxin',
#  'Botulinum toxin A',
#  'BTX-A',
#  'Evabotulinumtoxina',
#  'IncobotulinumtoxinA',
#  'OnabotulinumtoxinA',
#  'Prabotulinumtoxin A',
#  'DB00083',
#  'Pancrelipase',
#  'Pancrealipase',
#  'Pancreatic extract pancrelipase',
#  'Pancreatic protease',
#  'Pancreatin',
#  'Pancrelipase (amylase;lipase;protease)',
#  'DB00085',
#  'Streptokinase',
#  'Streptococcal fibrinolysin',
#  'DB00086',
#  'Alemtuzumab',
#  'DB00087',
#  'Alglucerase',
#  'DB00088',
#  'Capromab pendetide',
#  '(111In)-Capromab pendetide',
#  'Indium (111In) capromab pendetide',
#  'Indium 111 Capromab Pendetide',
#  'Indium In 111 capromab pendetide',
#  'DB00089',
#  'Laronidase',
#  'alpha-L-Idosiduronase',
#  'Human Recombinant alpha-L-iduronidase',
#  'Laronidase (genetical recombination)',
#  'DB00090',
#  'Alefacept',
#  'DB00092',
#  'Urofollitropin',
#  'Follitropin human',
#  'Urofollitrophin',
#  'DB00094',
#  'Efalizumab',
#  'anti-CD11a',
#  'antiCD11 alpha',
#  'DB00095',
#  'Choriogonadotropin alfa',
#  'Choriogonadotropin alpha',
#  'Chorionic gonadotropin (recombinant)',
#  'DB00097',
#  'Antithymocyte immunoglobulin (rabbit)',
#  'Anti-human thymocyte immunoglobulin, rabbit',
#  'Anti-T-lymphocyte immune globulin, rabbit',
#  'Anti-thymocyte globulin (rabbit)',
#  'Anti-thymocyte globulin rabbit',
#  'Antithymocyte immunoglobulin',
#  'Lapine T-lymphocyte immune globulin',
#  'Rabbit anti-human thymocyte globulin',
#  'Rabbit anti-human thymocyte globulin (rATG)',
#  'Rabbit anti-human thymocyte immunoglobulin',
#  'Rabbit anti-thymocyte immunoglobulin',
#  'Rabbit antithymocyte globulin',
#  'Rabbit ATG',
#  'rATG',
#  'Thymoglobulin',
#  'Thymoglobuline',
#  'DB00098',
#  'Filgrastim',
#  'Filgrastim-aafi',
#  'Filgrastim-sndz',
#  'G-CSF',
#  'Granulocyte Colony Stimulating Factor',
#  'Tbo-filgrastim',
#  'DB00099',
#  'Coagulation Factor IX (Recombinant)',
#  'Coagulation factor IX recombinant human',
#  'Factor IX (Recombinant)',
#  'nonacog alfa',
#  'nonacog gamma',
#  'Recombinant factor IX',
#  'DB00100',
#  'Becaplermin',
#  'PDGF-2',
#  'PDGF-BB',
#  'PDGFB',
#  'Platelet-derived growth factor BB, recombinant',
#  'Platelet-derived growth factor beta polypeptide',
#  'Recombinant platelet-derived growth factor BB',
#  'rhPDGF-BB',
#  'rPDGF-BB',
#  'SH-POLYPEPTIDE-59',
#  'DB00102',
#  'Agalsidase beta',
#  'Agalsidase alfa',
#  'Alpha-galactosidase A',
#  'DB00103',
#  'Interferon alfa-2b',
#  'Interferon alfa-2b, recombinant',
#  'Interferon alpha-2B',
#  'Intron (Interferon alpha2b)',
#  'Intron A',
#  'Intron A (Interferon alpha2b)',
#  'r-INF-alpha',
#  'rIFN-alpha-2b',
#  'DB00105',
#  'Oxytocin',
#  'DB00107',
#  'Natalizumab',
#  'Anti-alpha4 integrin',
#  'Anti-VLA4',
#  'DB00108',
#  'Enfuvirtide',
#  'DB00109',
#  'Palivizumab',
#  'DB00110',
#  'Daclizumab',
#  'Dacliximab',
#  'Daclizumab beta',
#  'DB00111',
#  'Bevacizumab',
#  'Anti-VEGF Humanized Monoclonal Antibody',
#  'Anti-VEGF monoclonal antibody',
#  'bevacizumab-awwb',
#  'rhuMAb-VEGF',
#  'DB00112',
#  'Technetium Tc-99m arcitumomab',
#  'Arcitumomab technetium-99m',
#  'Technetium (99mTc) arcitumomab',
#  'Technetium Tc 99m arcitumomab',
#  'Technetium-99m arcitumomab',
#  'DB00113',
#  'Eculizumab',
#  'DB01257',
#  'Panitumumab',
#  'ABX-EGF',
#  'DB01269',
#  'Ranibizumab',
#  'rhuFab V2',
#  'DB01270',
#  'Idursulfase',
#  'Alpha-L-iduronate sulfate sulfatase',
#  'Iduronate 2-sulfatase',
#  'DB01271',
#  'Alglucosidase alfa',
#  'Acid maltase',
#  'Acid-alpha glucosidase',
#  'Aglucosidase alfa',
#  'Aglucosidase alpha',
#  'alpha-1,4-glucosidase',
#  'Alpha-glucosidase',
#  'Lysosomal Alpha-Glucosidase',
#  'DB01272',
#  'Exenatide',
#  'Exenatide synthetic',
#  'Exendin 4',
#  'Exendin-4',
#  'Synthetic exendin-4',
#  'DB01276',
#  'Mecasermin',
#  'Human somatomedin C',
#  'Mecasermin recombinant',
#  'Mechano growth factor',
#  'DB01277',
#  'Galsulfase',
#  'Arylsulfatase B galsulfase',
#  'Galsulfase (genetical recombination)',
#  'DB01279',
#  'Abatacept',
#  'Abatacept recombinant',
#  'DB01281',
#  'Corticotropin',
#  'ACTH',
#  'Adrenocorticotrophin',
#  'Adrenocorticotropic hormone',
#  'Corticotrophin',
#  'Cortigel',
#  'H.P. acthar gel',
#  'DB01285',
#  'Insulin aspart',
#  'Aspart',
#  'Aspart Insulin',
#  'B28-Aspart-Insulin',
#  'Insulin aspart protamine',
#  'Insulin aspart protamine recombinant',
#  'Insulin aspart recombinant',
#  'Insulin X14',
#  'Insulin, aspart protamine, human',
#  'Insulin, aspart, human',
#  'Insulin,aspart protamine',
#  'DB01306',
#  'Insulin detemir',
#  'Detemir',
#  'Insulin detemir recombinant',
#  'Insulin,detemir,human',
#  'DB01307',
#  'Insulin glulisine',
#  'Insulin Glulisine (recombinant DNA origin)',
#  'Insulin glulisine recombinant',
#  'DB01309',
#  'Ephedra sinica root',
#  'Cao ma huang root',
#  'Chinese ephedra root (ephedra sinica)',
#  'Chinese jointfir',
#  'Ephedra',
#  'Ephedra ma-huang root',
#  'Ephedra root (ephedra sinica)',
#  'Ephedrae radix',
#  'Hemp yellow root',
#  'Ma huang gen (ephedra sinica)',
#  'Mahuanggen (ephedra sinica)',
#  'DB01363',
#  'Ginkgo biloba',
#  'Common ginkgo leaf',
#  'Ginkgo',
#  'Ginkgo biloba extract',
#  'Ginkgo biloba leaf',
#  'Ginkgo biloba leaf dry extract',
#  'Ginkgo biloba leaf tincture',
#  'Ginkgo extract',
#  'Ginkgo folium',
#  'Ginkgo leaf',
#  'Ginkgo macrophylla leaf',
#  'Maidenhair extract',
#  'Maidenhair tree leaf',
#  'Pterophyllus salisburiensis leaf',
#  'Salisburia adiantifolia leaf',
#  'Salisburia biloba leaf',
#  'Salisburia ginkgo leaf',
#  'Salisburia macrophylla leaf',
#  'Tanakan',
#  'Yinxingye',
#  'DB01381',
#  'Hemin',
#  'chloro(protoporphyrinato)iron(III)',
#  'protohemin',
#  'DB03404',
#  'Pegaptanib',
#  'EYE 001',
#  'NX 1838',
#  'NX1838',
#  'Pegaptanib Octasodium',
#  'Pegaptanib sodium',
#  'DB04895',
#  'Lucinactant',
#  'ATI-02',
#  'KL4-surfactant',
#  'DB04897',
#  'Nesiritide',
#  'BNP',
#  'BNP-32',
#  'Brain natriuretic peptide 32',
#  'Human brain natriuretic factor-32',
#  'Nesiritide recombinant',
#  'DB04899',
#  'Thymalfasin',
#  'Thymosin alpha1 (human)',
#  'DB04900',
#  'Galiximab',
#  'Anti-CD80 monoclonal antibody',
#  'DB04901',
#  'Sitimagene ceradenovec',
#  'DB04907',
#  'G17DT',
#  'Antigastrin 17',
#  'Gastrin 17 immunogen',
#  'Gastrin 17 vaccine',
#  'DB04914',
#  'Alfimeprase',
#  'DB04919',
#  'Desmoteplase',
#  'DSPA desmoteplase',
#  'rDSPA alpha 1',
#  'Salivary plasminogen activator alpha 1, Desmodus rotundus',
#  'DB04925',
#  'Defibrotide',
#  'Defibrotide free acid',
#  'Defibrotide free acid (porcine mucosa)',
#  'Defibrotide free acid (porcine)',
#  'DB04932',
#  'Pexelizumab',
#  '5G1.1-sc',
#  'h5G1.1-scFv',
#  'DB04949',
#  'Ranpirnase',
#  'DB04950',
#  'Afelimomab',
#  'DB04956',
#  'Epratuzumab',
#  'IMMU-HLL2',
#  'DB04958',
#  'Verpasep caltespen',
#  'BCG65-E7',
#  'Heat-shock protein HSP 65 (Mycobacterium BCG) fusion protein with transcription factor E7 (human papillomavirus 16)',
#  'HPV 16 E7/HSP65 vaccine',
#  'HPV E7 Peptide Epitope Vaccine',
#  'HspE7',
#  'DB04959',
#  'Bectumomab',
#  'DB04962',
#  'Oregovomab',
#  'Monoclonal antibody B43.13',
#  'Oregovamab',
#  'DB04964',
#  'LErafAON',
#  'DB04973',
#  'Tigapotide',
#  'DB04985',
#  'IGN311',
#  'DB04988',
#  'Adecatumumab',
#  'DB05006',
#  'Abaloparatide',
#  'DB05084',
#  'Labetuzumab',
#  'hMN-14',
#  'MAb hMN14',
#  'Monoclonal antibody hMN-14',
#  'DB05097',
#  'Ancrod',
#  'DB05099',
#  'Matuzumab',
#  'DB05101',
#  'VIR201',
#  'DB05110',
#  'Fontolizumab',
#  'DB05111',
#  '1D09C3',
#  'DB05121',
#  'Bavituximab',
#  'DB05136',
#  'CR002',
#  'DB05139',
#  'PEV3A',
#  'DB05144',
#  'CMLVAX100',
#  'DB05164',
#  'Egaptivon pegol',
#  'DB05202',
#  'Rozrolimupab',
#  'Recombinant human antigen-specific polyclonal antibody (pAb) against RhD antigen expressed in Chinese hamster ovary cells',
#  'DB05209',
#  'PN0621',
#  'DB05218',
#  'KB001',
#  'DB05222',
#  'Fibrinolysin',
#  'Bovine Fibrinolysin',
#  'Bovine Plasmin',
#  'Fibrinolysin (human)',
#  'Fibrinolysin, human',
#  'Plasmin (bos taurus)',
#  'Plasmin (bovine)',
#  'Plasmin bovine',
#  'DB05254',
#  'Interferon alfa',
#  'HuIFN-alpha-Le',
#  'IFN-alpha',
#  'Natural alpha interferon',
#  'DB05258',
#  'Glatiramer',
#  '(T,G)-A-L',
#  'COP 1',
#  'COP-1',
#  'Copolymer I (synthetic peptide)',
#  'Copolymer-1',
#  'DB05259',
#  'Hepatitis B Immune Globulin',
#  'HBIG',
#  'Hepatitis B Immune Globulin (Human)',
#  'Hepatitis B immune globulin human',
#  'Hepatitis B immunoglobulin (human)',
#  'Human hepatitis B immunoglobulin',
#  'Human hepatitis B virus immune globulin',
#  'Human hepatitis-B immunoglobulin',
#  'DB05276',
#  'keyhole limpet hemocyanin',
#  'DB05299',
#  'Girentuximab',
#  'DB05304',
#  'Cintredekin Besudotox',
#  'DB05305',
#  'Alferminogene tadenovec',
#  'Ad5FGF-4',
#  'DB05306',
#  'Ecallantide',
#  'DB05311',
#  'Oportuzumab monatox',
#  'DB05319',
#  'PEG-uricase',
#  'DB05321',
#  'INGN 225',
#  'DB05325',
#  'Romiplostim',
#  'DB05332',
#  'Obiltoxaximab',
#  'DB05336',
#  'SOT-107',
#  'DB05337',
#  'Regramostim',
#  'Colony-stimulating factor 2 (human clone pCSF-1 protein moiety reduced), glycoform GMC 89-107',
#  'GM-CSF',
#  'rhGm-CSF',
#  'DB05386',
#  'Albinterferon Alfa-2B',
#  'alb-IFN',
#  'Albinterferon',
#  'Albuferon alpha',
#  'Albumin-interferon alpha',
#  'DB05396',
#  'XTL-001',
#  'DB05405',
#  'CAT-213',
#  'DB05429',
#  'NAV 1800',
#  'RIGScan CR',
#  'RIGScan CR49',
#  'DB05437',
#  'Briakinumab',
#  'DB05459',
#  'SGN-30',
#  'DB05471',
#  'Recombinant alpha 1-antitrypsin',
#  'DB05481',
#  'Otelixizumab',
#  'DB05496',
#  'CPG 10101',
#  'DB05530',
#  'AMG 108',
#  'DB05545',
#  'Iratumumab',
#  'DB05550',
#  'Enokizumab',
#  '7F3com-2H2',
#  '7F3com2H2',
#  'DB05555',
#  'Ramucirumab',
#  'DB05578',
#  'Farletuzumab',
#  'DB05595',
#  'Veltuzumab',
#  'DB05656',
#  'EP-2104R',
#  'DB05675',
#  'Ustekinumab',
#  'Stelera',
#  'DB05679',
#  'FX06',
#  'DB05685',
#  'Maxy-G34',
#  'DB05718',
#  'CYT006-AngQb',
#  'DB05739',
#  'CYT007-TNFQb',
#  'DB05758',
#  'LLL-3348',
#  'DB05771',
#  'Trastuzumab emtansine',
#  'Ado-trastuzumab',
#  'Ado-trastuzumab emtansine',
#  'T-DM1',
#  'Trastuzumab-DM1',
#  'Trastuzumab-MCC-DM1',
#  'DB05773',
#  'Thrombomodulin Alfa',
#  'Thrombomodulin (human 498-amino acid fragment)',
#  'DB05777',
#  'LM-609',
#  'DB05787',
#  'PRO-542',
#  'DB05793',
#  'Serelaxin',
#  'Human relaxin 2 (relaxin h2)',
#  'Human relaxin recombinant',
#  'Recombinant human relaxin',
#  'DB05794',
#  'TNX-901',
#  'DB05797',
#  'GEM-231',
#  'DB05798',
#  'NBI-6024',
#  'DB05819',
#  'Parathyroid hormone',
#  'Parathormone',
#  'Parathormone (human recombinant)',
#  'Parathyrin',
#  'Parathyroid hormone (1-84) human recombinant',
#  'Parathyroid hormone (rDNA)',
#  'PTH',
#  'PTH(1-84)',
#  'rhPTH',
#  'rhPTH(1-84)',
#  'rPTH',
#  'rPTH(1-84)',
#  'DB05829',
#  'humanized SMART Anti-IL-12 Antibody',
#  'DB05848',
#  'Peginterferon alfacon-1',
#  'PEG INF alfacon-1',
#  'PEG-Alfacon',
#  'PEG-Infergen',
#  'PEG-interferon alfacon-1',
#  'Pegylated interferon alfacon-1',
#  'DB05860',
#  '99mTc-14 F7 Mab',
#  'DB05867',
#  'AME-527',
#  'DB05879',
#  'ABX-PTH',
#  'DB05883',
#  'Inotuzumab ozogamicin',
#  'DB05889',
#  'RI 624',
#  'DB05892',
#  'HGS-TR2J',
#  'DB05895',
#  'CCR5 mAb',
#  'DB05906',
#  'MYO-029',
#  'DB05915',
#  'CT-011',
#  'DB05916',
#  'Leronlimab',
#  'DB05941',
#  'GI-5005',
#  'DB05942',
#  'MDX-1303',
#  'DB05945',
#  'Glembatumumab vedotin',
#  'DB05996',
#  'Eteplirsen',
#  '(P-deoxy-P-(dimethylamino)](2&apos;,3&apos;-dideoxy-2&apos;,3&apos;-imino-2&apos;,3&apos;-seco)(2&apos;a--&gt;5&apos;)(C-m5U-C-C-A-A-C-A-m5U-C-A-A-G-G-A-A-G-A-m5U-G-G-C-A-m5U-m5U-m5U-C-m5U-A-G),5&apos;-(P-(4-((2-(2-(2-hydroxyethoxy)ethoxy)ethoxy)carbonyl)-1-piperazinyl)-N,N-dimethylphosphonamidate) RNA',
#  'DB06014',
#  'GlycoPEG-GCSF',
#  'DB06022',
#  'Olaratumab',
#  'DB06043',
#  'IPH 2101',
#  'DB06049',
#  'TB-402',
#  'DB06050',
#  'Caplacizumab',
#  'caplacizumab-yhdp',
#  'DB06081',
#  'IMC-1C11',
#  'DB06101',
#  'Eldelumab',
#  'DB06116',
#  'Lumiliximab',
#  'Gomiliximab',
#  'DB06162',
#  'Canakinumab',
#  'DB06168',
#  'Paclitaxel trevatide',
#  ...]

# %%
l1000_names = list(pert_info['pert_iname'].values)

# %%
l1000_names = [name.lower() for name in l1000_names]

# %%
l1000_names
# Out:
# ['akt2',
#  'hsf1',
#  'nfe2l2',
#  'abl1',
#  'abl1',
#  'ache',
#  'acvr1',
#  'acvr1',
#  'acvr1',
#  'acvr1|acvr1|acvr1|acvr1|acvrl1|acvrl1|acvrl1|acvrl1',
#  'acvr1|acvr1|acvr1|acvr1|acvrl1|acvrl1|acvrl1|acvrl1',
#  'acvr1|acvr1|acvr1|acvr1|acvrl1|acvrl1|acvrl1|acvrl1',
#  'acvr1|acvr1|acvr1|acvr1|acvrl1|acvrl1|acvrl1|acvrl1',
#  'adm',
#  'agt',
#  'ahsg',
#  'aimp1',
#  'akt2',
#  'alk',
#  'alk',
#  'alk',
#  'ang',
#  'angpt1',
#  'angpt2',
#  'angpt4',
#  'apcs',
#  'apln',
#  'apoa4',
#  'apoe',
#  'areg',
#  'artn',
#  'avp',
#  'b2m',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bcr-abl',
#  'bdnf',
#  'bglap',
#  'bmp10',
#  'bmp11',
#  'bmp13',
#  'bmp2',
#  'bmp4',
#  'bmp6',
#  'bmp7',
#  'bmpr1b',
#  'bmpr2',
#  'bmpr2',
#  'braf',
#  'braf',
#  'braf',
#  'braf',
#  'braf',
#  'braf',
#  'braf',
#  'braf',
#  'braf',
#  'braf',
#  'braf',
#  'braf',
#  'nifurtimox',
#  '5-hydroxytryptophan',
#  'hemado',
#  'sa-3676',
#  'brd-a00474148',
#  'af-dx-116',
#  'biperiden',
#  'brd-a00626522',
#  'noretynodrel',
#  'brd-a00763758',
#  'dyphylline',
#  'alprenolol',
#  'hexestrol',
#  'zebularine',
#  '7-hydroxy-pipat',
#  '7,8-dihydro-l-biopterin',
#  'salmeterol',
#  'flumetasone',
#  'chlormadinone-acetate',
#  'bupivacaine',
#  'prednisolone-acetate',
#  'naftopidil',
#  'xanthinol',
#  'brd-a01960364',
#  'brd-a01973626',
#  'brd-a01999384',
#  'nitrendipine',
#  'tubaic-acid',
#  'betamethasone',
#  'met-leu-phe',
#  'emf-sumo1-9',
#  'brd-a02241946',
#  'cyclopamine',
#  'ethinyl-estradiol',
#  'importazole',
#  'etoposide',
#  'meptazinol',
#  'dihydrodeoxygedunin',
#  'brd-a02726762',
#  'brd-a02747686',
#  'betaxolol',
#  'arg-tc-41',
#  'brd-a02836799',
#  'lofexidine',
#  'micropenin',
#  'alizapride',
#  'mepivacaine',
#  'ritonavir',
#  'ici-89406',
#  'sulindac',
#  'brd-a03436432',
#  'st-014366',
#  'metoprolol',
#  'brd-a03684405',
#  'brd-a03772856',
#  'cp-55940',
#  'st-014147',
#  'brd-a03946276',
#  'l-buthionine-sulfoximine',
#  'yo-2',
#  'brd-a04172077',
#  'skf-83959',
#  'genipin',
#  'synephrine',
#  'brd-a04332542',
#  'maraviroc',
#  'brd-a04392722',
#  'skf-82958',
#  'chlorphenamine',
#  'cgp-52432',
#  'bucladesine',
#  'norgestimate',
#  '2-aminotetralin',
#  'bupropion',
#  'ipratropium',
#  'bay-k8644',
#  'brd-a05565054',
#  'dinorcitalopram-oxalate',
#  'brd-a05680309',
#  'brd-a05729358',
#  'brd-a05831822',
#  'dl-tboa',
#  'brd-a06131576',
#  'brd-a06276885',
#  'alvespimycin',
#  'terfenadine',
#  'sb-218078',
#  'hydroquinidine',
#  'brd-a06641369',
#  'brd-a06664848',
#  'dibutyrylcyclic-gmp',
#  'brd-a06779035',
#  'mrs-1334',
#  'brd-a06909528',
#  'cvf-sumo-13',
#  'hydrocortisone-hemisuccinate',
#  'ipratropium',
#  'tryptophan',
#  'esmolol',
#  'labetalol',
#  'brd-a07614565',
#  'epinephrine-(racemic)',
#  'orciprenaline',
#  'flavanone',
#  'cilnidipine',
#  'vigabatrin',
#  'metitepine',
#  'rhodomyrtoxin-b',
#  'deoxycholic-acid',
#  'methyl-testosterone',
#  'racecadotril',
#  'melphalan',
#  'famprofazone',
#  'brd-a08610364',
#  'brd-a08658758',
#  'iodixanol',
#  'brd-a08662020',
#  'heliotrine',
#  'brd-a08778300',
#  'cephalotaxine',
#  'brd-a09053961',
#  'alfuzosin',
#  'amyleine',
#  'chlorpromazine',
#  'strychnine',
#  'nomilin',
#  'brd-a09164687',
#  'st-024029',
#  'norethindrone',
#  'mebeverine',
#  'flecainide',
#  'bicuculline',
#  'verapamil',
#  'homatropine',
#  'brd-a09719808',
#  'cyclophosphamide',
#  'st-023431',
#  'skf-81297',
#  'etilefrine',
#  'brd-a09984573',
#  'propranolol',
#  'dexamethasone',
#  'talampicillin',
#  'brd-a10330754',
#  'norketamine',
#  'ascorbic-acid',
#  'vanillyl-glycol',
#  'cyclopiazonic-acid',
#  'gsk-429286a',
#  'talampicillin',
#  'prenylamine',
#  'sulpiride',
#  'imiloxan',
#  'ambelline',
#  'carvedilol',
#  'bci-hydrochloride',
#  'brd-a11009626',
#  'brd-a11087911',
#  'brd-a11095214',
#  'nadide',
#  'nor-binaltorphimine',
#  'pravastatin',
#  'azacitidine',
#  'dihydroobliquin',
#  'brd-a11512624',
#  'thiocolchicoside',
#  'sb-205607',
#  'wortmannin',
#  'chromomycin-a3',
#  'triciribine',
#  'brd-a11731846',
#  'enilconazole',
#  'am-92016',
#  'brd-a11929187',
#  'brd-a11968133',
#  'lorazepam',
#  'ly-278584',
#  'brd-a12083771',
#  'nutlin-3',
#  'orteronel',
#  'brd-a12426960',
#  'nitrendipine',
#  'brd-a12633378',
#  'brd-a12643502',
#  'streptozotocin',
#  'serotonin',
#  'brd-a13020530',
#  'troglitazone',
#  'triptolide',
#  'fluorometholone',
#  'doxazosin',
#  'stk-064652',
#  'brd-a13346522',
#  'brd-a13367427',
#  'brd-a13461302',
#  'flucloxacillin',
#  'alcuronium',
#  'ha-14-1',
#  'brd-a13914662',
#  'sulindac',
#  'brd-a13964793',
#  'ephedrine',
#  'brd-a14014306',
#  'brd-a14178283',
#  'oxyphenonium',
#  'octopamine',
#  'mesoridazine',
#  'scopolamine',
#  'ub-165',
#  'bucladesine',
#  'valsartan',
#  'brd-a14795281',
#  'mestranol',
#  'alaproclate',
#  'skf-83822',
#  'l-ascorbyl-6-palmitate',
#  'geranyl-geranyl-pyrophosphate',
#  'hu-211',
#  'bergenin',
#  'bucladesine',
#  'phorbol-12-myristate-13-acetate',
#  'avicin-d',
#  'brd-a15113563',
#  'benazepril',
#  'fluocinolone-acetonide',
#  'gw-1929',
#  'bmy-14802',
#  'tetracycline',
#  'brd-a15501135',
#  'sdz-21009',
#  'picrotoxin',
#  'rebamipide',
#  '4-hydroxy-2-nonenal',
#  'bucladesine',
#  'profenamine',
#  'modafinil',
#  'acarbose',
#  'amcinonide',
#  'brd-a16581344',
#  'butoconazole',
#  'badge',
#  'isoxsuprine',
#  'podophyllotoxin',
#  'ampicillin',
#  'brd-a16820783',
#  'nalbuphine',
#  'etodolac',
#  'rhizocarpic-acid',
#  'brefeldin-a',
#  'brd-a17081056',
#  'bg-1015',
#  'carprofen',
#  'bw-723c86',
#  'beclometasone',
#  'mdl-72832',
#  'bambuterol',
#  'gelsemine',
#  'beta-alanine',
#  'ibuprofen',
#  'brd-a17664363',
#  'brd-a17718497',
#  'alpha-methylserotonin',
#  'brd-a17757596',
#  'gedunin',
#  'fulvestrant',
#  'trolox',
#  'lenalidomide',
#  'phensuximide',
#  'cpccoet',
#  'monoethylhexylphthalate',
#  'brd-a18279961',
#  'brd-a18411371',
#  'etoposide',
#  'brd-a18477699',
#  '5-iodotubercidin',
#  'brd-a18573497',
#  'wiskostatin',
#  'hexetidine',
#  'estriol',
#  'idazoxan',
#  'brd-a18725729',
#  'bax-channel-blocker',
#  '(+/-)-7-hydroxy-2-(n,n-di-n-propylamino)tetralin',
#  'estradiol',
#  'cytarabine',
#  'haematoxylin-pentaacetate',
#  'trichostatin-a',
#  'pseudopelletierine',
#  'a-23187',
#  'trimipramine',
#  '1,2-propylene-glycol',
#  'latrunculin-b',
#  'vinpocetine',
#  'geldanamycin',
#  'perhexiline',
#  'mianserin',
#  'ondansetron',
#  'lomatin',
#  'brd-a19928752',
#  'closantel',
#  'mecamylamine',
#  'medrysone',
#  "2',5'-dideoxyadenosine",
#  'atenolol-(+/-)',
#  'danazol',
#  'chlormezanone',
#  'brd-a20488704',
#  'ib-meca',
#  'dihydroxyphenylglycine',
#  'thiostrepton',
#  'vancomycin',
#  'vu-0447126-2',
#  'isosalsoline',
#  'dopamine',
#  'way-213613',
#  'merbromin',
#  'hemicholinium-3',
#  'brd-a21406558',
#  'brd-a21481508',
#  'fluoxymesterone',
#  'brivanib',
#  'naltriben',
#  'brd-a21812217',
#  'praziquantel',
#  'amlodipine',
#  'metrifonate',
#  'estropipate',
#  'tridihexethyl',
#  'terazosin',
#  'brd-a22272113',
#  'benfluorex',
#  'pantoprazole',
#  'brd-a22514244',
#  'procaterol',
#  'sb-205384',
#  'bvt-948',
#  'oxytetracycline',
#  'homochlorcyclizine',
#  'vinblastine',
#  'tenoxicam',
#  'pinacidil',
#  'cct036477',
#  'clindamycin',
#  'pheniramine',
#  'estradiol',
#  'westcort',
#  'sibutramine',
#  'oxymetholone',
#  'nas-181',
#  'avermectin',
#  'bacitracin',
#  'paclitaxel',
#  'sirtinol',
#  'sirolimus',
#  'rifabutin',
#  'brd-a24021119',
#  'brd-a24054354',
#  'saclofen',
#  'ifenprodil',
#  'brd-a24225650',
#  'ofloxacin',
#  'zeranol',
#  'celastrol',
#  'nadifloxacin',
#  'butylscopolammonium',
#  'be-2254',
#  'warfarin',
#  'nornicotine',
#  'homoharringtonine',
#  'laudanosine',
#  'nimodipine',
#  'brd-a24951056',
#  'erastin',
#  'rti-55',
#  'benzatropine',
#  'cvf-sumo-7',
#  'hydrocortisone-valerate',
#  'brd-a25170757',
#  'aminoglutethimide',
#  'at-sumo-1',
#  'brd-a25416824',
#  'ki-16425',
#  'streptozotocin',
#  'fadrozole',
#  'emetine',
#  'securinine',
#  'brd-a25829966',
#  'st-4034902',
#  'verrucarin-a',
#  'zaldaride',
#  'clobetasol',
#  'bulleyaconitine-a',
#  'salsolinol',
#  'calmidazolium',
#  'brd-a26333730',
#  'propafenone',
#  'brd-a26347577',
#  'chlorthalidone',
#  'brd-a26583774',
#  'brd-a26595446',
#  'brd-a26627799',
#  'nicardipine',
#  'vu-0447127-2',
#  'cyclopiazonic-acid',
#  'isamoltane',
#  'brd-a26962727',
#  'diarylpropionitrile',
#  'rolitetracycline',
#  'altrenogest',
#  'brd-a27640568',
#  'prednisolone',
#  'brd-a27924917',
#  'etiocholanolone',
#  'zonisamide',
#  'cucurbitacin-i',
#  'aminomethyltransferase',
#  'brd-a28412351',
#  'l-689560',
#  'brd-a28422330',
#  'paclitaxel',
#  'tetrahydrozoline',
#  'trichlormethiazide',
#  'puromycin',
#  'azd-1480',
#  'gitoxigenin',
#  'brd-a29119732',
#  'acebutolol',
#  'pca-4248',
#  'canrenoic-acid',
#  'brd-a29342309',
#  'dropropizine',
#  'carbinoxamine',
#  'rwj-21757',
#  'bicalutamide',
#  'nomifensine',
#  'brd-a29721261',
#  '17-hydroxyprogesterone-caproate',
#  'disopyramide',
#  'lorglumide',
#  'kin001-127',
#  'brd-a30083233',
#  'dithiothreitol',
#  'ethotoin',
#  'brd-a30395175',
#  'metergoline',
#  'camptothecin',
#  'brd-a30455275',
#  'tiletamine',
#  'mr-16728',
#  'brd-a30612536',
#  'lfm-a13',
#  'diperodon',
#  'triamcinolone',
#  'felodipine',
#  'brd-a30856524',
#  'nifedipine',
#  'sdz-wag-994',
#  'brefeldin-a',
#  'calcipotriol',
#  'fluoxetine',
#  'brd-a31180007',
#  'tcb2',
#  'mitotane',
#  'kynuramine',
#  'montelukast',
#  'fludarabine',
#  'brd-a31429689',
#  'methocarbamol',
#  'cgp-20712',
#  'procyclidine',
#  'formestane',
#  'cyanocobalamin',
#  'brd-a31946439',
#  'brd-a32065788',
#  'carbetocin',
#  'methyllycaconitine',
#  'brd-a32214171',
#  'brd-a32241587',
#  'methyl-angolensate',
#  'brd-a32440707',
#  'brd-a32449311',
#  'brd-a32582647',
#  'bjm-csc-15',
#  'leu-enkephalin',
#  'brd-a32917072',
#  'mrs-1845',
#  'heptaminol',
#  'bacampicilline',
#  "5'-guanidinonaltrindole",
#  'tioconazole',
#  'sotalol',
#  'st-208960',
#  'oxfendazole',
#  'metixene',
#  'avicin-g',
#  'oxyphenbutazone',
#  'ter-14687',
#  'scopolamine',
#  'suprofen',
#  'kuc107191n',
#  'suloctidil',
#  'vu-0404997-2',
#  'rolipram',
#  'budesonide',
#  'zopiclone',
#  'brd-a34421300',
#  'tigecycline',
#  'ambrisentan',
#  'cgp-12177',
#  'homosalate',
#  'proscillaridin',
#  'itraconazole',
#  'rutin',
#  'ku-c103676',
#  'eriodictyol',
#  'brd-a35072120',
#  'dexamethasone',
#  'brd-a35141262',
#  'brd-a35153197',
#  'brd-a35207501',
#  'mannitol',
#  'neca',
#  'brd-a35430844',
#  'l-803087',
#  'benidipine',
#  'teniposide',
#  'cgp-37157',
#  'furaltadone',
#  'brd-a35769934',
#  'verteporfin',
#  'brd-a35825362',
#  'ibrutinib',
#  'pregnenolone-succinate',
#  'megestrol-acetate',
#  'amcinonide',
#  'brd-a36059655',
#  'estradiol-benzoate',
#  'remacemide',
#  'genistein',
#  'brd-a36165599',
#  'sulfinpyrazone',
#  'buphenine',
#  'brd-a36275421',
#  'necrostatin-1',
#  'brd-a36411721',
#  'biperiden',
#  'sn-38',
#  'hydroxycholesterol',
#  'brd-a36884011',
#  'physostigmine',
#  'amfepramone',
#  'brl-52537',
#  'ipratropium',
#  'hydralazine',
#  'iocetamic-acid',
#  'brd-a37501891',
#  'naloxone',
#  'daunorubicin',
#  'brd-a37656721',
#  'sb-203580',
#  'brd-a37735495',
#  'ici-204448',
#  'triamcinolone',
#  'picrotoxin',
#  'anthothecol',
#  'cyclazosin',
#  'safrolglycol',
#  'eucatropine',
#  'estrone',
#  'cyclosporin-a',
#  'glafenine',
#  'atovaquone',
#  'st-019366',
#  'brd-a38425832',
#  'ku-14r',
#  'fludrocortisone-acetate',
#  'brd-a38793261',
#  'bl-077',
#  'gw-311616',
#  'bh3i-1',
#  'brd-a38936397',
#  'mosapride',
#  'k784-3187',
#  'brd-a39121618',
#  'ampiroxicam',
#  'methoxamine',
#  'chlortetracycline',
#  'chlorphenesin-carbamate',
#  'dcpib',
#  'epibatidine',
#  'cyproterone',
#  'rabeprazole',
#  'norethisterone',
#  'omdm-2',
#  'brd-a39599596',
#  'hc-toxin',
#  'homatropine',
#  'estradiol-valerate',
#  'sisomicin',
#  'eplerenone',
#  'brd-a39986918',
#  'radicicol',
#  'brd-a40163033',
#  'brd-a40431293',
#  'brd-a40560522',
#  'ketorolac',
#  'sib-1508y',
#  'minocycline',
#  'oleanolic-acid',
#  'brd-a41114263',
#  'methoprene-acid',
#  'brd-a41228941',
#  'gp-42',
#  'cyclopenthiazide',
#  'bongkrek-acid',
#  'practolol',
#  'tosufloxacin',
#  'pk-11195',
#  'ezetimibe',
#  'chlortetracycline',
#  'brd-a41630653',
#  'brd-a41649729',
#  'tgx-221',
#  'sulmazole',
#  'naloxone',
#  'vitexin',
#  'brd-a41986761',
#  'brucine',
#  'brd-a41997916',
#  'vu-0415555-1',
#  'formestane',
#  'carteolol',
#  'brd-a42187224',
#  'ehpg-piperazine',
#  'tenatoprazole',
#  'alexidine',
#  'metanephrine',
#  'actinomycin-d',
#  'benproperine',
#  'l-152804',
#  'cetirizine',
#  'brd-a42610307',
#  'iopanoic-acid',
#  'triciribine',
#  'brd-a42737819',
#  'ornidazole',
#  'tetrahydrocannabinol-7-oic-acid',
#  'brd-a42969626',
#  'brd-a42994615',
#  'loxoprofen',
#  'brd-a43087975',
#  'brd-a43126523',
#  'penicillic-acid',
#  'brd-a43155244',
#  'brd-a43188678',
#  'ethinyl-estradiol',
#  'niguldipine',
#  'monocrotaline',
#  'brd-a43640821',
#  'oxprenolol',
#  'brd-a43805296',
#  'clobutinol',
#  'karakoline',
#  'pinacidil',
#  'brd-a43885598',
#  'l-368899',
#  'tetrahydropalmatine',
#  'reboxetine',
#  'tranylcypromine',
#  'doxylamine',
#  'indoprofen',
#  'azasetron',
#  'brd-a44244100',
#  'pentobarbital',
#  'lfm-a12',
#  'dihydroergocristine',
#  'mifepristone',
#  'erythromycin',
#  'brd-a44862234',
#  'proglumide',
#  'meclocycline',
#  'brd-a45206415',
#  'periplocymarin',
#  'wye-125132',
#  'ubp-302',
#  'metrizamide',
#  'brd-a45657137',
#  'iloprost',
#  'mepacrine',
#  'doxapram',
#  'hydrocortisone-phosphate',
#  'promethazine',
#  'tetramisole',
#  'ouabain',
#  'brd-a46802340',
#  'huperzine-a',
#  'dihydro-7-desacetyldeoxygedunin',
#  'garcinol',
#  'naltrindole',
#  'mevalonic-acid',
#  'dipivefrine',
#  'calyculin',
#  'tetrabenazine',
#  'citalopram',
#  'npc-15199',
#  'buthionine-sulfoximine',
#  'brd-a47714657',
#  'brd-a47816767',
#  'artesunate',
#  'brd-a47832959',
#  'cyanopindolol',
#  'brd-a48052484',
#  'trihexyphenidyl',
#  'mitomycin-c',
#  'phccc',
#  'argatroban',
#  'salsoline',
#  'nor-1-chlorpromazine',
#  'pioglitazone',
#  'ivermectin',
#  'mibefradil',
#  'testosterone-propionate',
#  'ib-meca',
#  'metacycline',
#  'skf-89976a',
#  'galantamine',
#  'donepezil',
#  'lansoprazole',
#  'alimemazine',
#  'ciprofibrate',
#  'ro-60-0175',
#  'desoximetasone',
#  'brd-a49581300',
#  'cucurbitacin-i',
#  'foliosidine',
#  'fludroxycortide',
#  'brd-a49848186',
#  'scopolamine-n-oxide',
#  'terbutaline',
#  'sirolimus',
#  'misoprostol',
#  'meclizine',
#  'veliparib',
#  'brd-a50388635',
#  'pd-0325901',
#  'fipronil',
#  'fenoldopam',
#  'cgk-733',
#  'mdl-73005ef',
#  'cvf-sumo-11',
#  'nk26-i-41-1',
#  'norgestrel',
#  'l-744832',
#  'jmv-431',
#  'chloramphenicol',
#  'tribenoside',
#  'cyproterone',
#  'fosinopril',
#  'noscapine',
#  'yohimbine',
#  'brd-a51666293',
#  'kw-06',
#  'venlafaxine',
#  'vu-0418933-1',
#  'econazole',
#  'brl-15572',
#  'norfenfluramine',
#  'brd-a51929314',
#  'halofantrine',
#  'vu-0413807-2',
#  'withaferin-a',
#  'lacidipine',
#  'isogedunin',
#  'doxorubicin',
#  'brd-a52530852',
#  'skf-83566',
#  'thiostrepton',
#  'brd-a52647795',
#  'ingenol',
#  'tetrindole',
#  'brd-a52771319',
#  'totaralolal',
#  'antimycin-a',
#  'brd-a52933579',
#  '15-delta-prostaglandin-j2',
#  'tetracycline',
#  'tianeptine',
#  'brd-a53107311',
#  'epitestosterone',
#  'brd-a53271750',
#  'ceramide',
#  'orphenadrine',
#  'km-04644sc',
#  'prilocaine',
#  'bg-1008',
#  'irl-2500',
#  'brd-a54077041',
#  'brd-a54194844',
#  'ephedrine-(racemic)',
#  'napelline',
#  'cortisone-acetate',
#  'pirlindole',
#  'solifenacin',
#  'brd-a54632525',
#  'levopropoxyphene',
#  'dihydroergotamine',
#  'etomidate',
#  'kf-38789',
#  'stk-674938',
#  'sulpiride',
#  'brd-a55317422',
#  'cgp-54626',
#  'testosterone',
#  'colforsin',
#  'methotrexate',
#  'mephenesin',
#  'bntx',
#  'brd-a55554369',
#  'brd-a55565369',
#  'vinblastine',
#  'brd-a55609290',
#  'h-7',
#  'phylloquinone',
#  'primaquine',
#  'bw-b70c',
#  'omeprazole',
#  'brd-a56001686',
#  'thiorphan',
#  'ca-074-me',
#  'reichstein',
#  'zileuton',
#  'fludrocortisone',
#  'epirubicin',
#  'px-12',
#  'altizide',
#  'nystatin',
#  'bafilomycin',
#  'brd-a56800788',
#  'brd-a56831909',
#  'esomeprazole',
#  'sq-22536',
#  'peruvoside',
#  'brd-a57107094',
#  'chlorcyclizine',
#  'cgs-21680',
#  'farnesylpyrophosphate',
#  'brd-a57300602',
#  'piroxicam',
#  'vu-0400071-3',
#  'norcitalopram',
#  'citiolone',
#  'nimodipine',
#  'butabindide',
#  'pinacidil',
#  'deoxyandirobin',
#  'y-27632',
#  'brd-a58482795',
#  'selamectin',
#  'budesonide',
#  'afatinib',
#  'ribostamycin',
#  'brd-a58924247',
#  'sulforaphane',
#  'brd-a59046243',
#  'brd-a59145032',
#  'ritodrine',
#  'k784-3391',
#  'viloxazine',
#  'lobelanidine',
#  'quinethazone',
#  'col-3',
#  'brd-a59728941',
#  'guggulsterone',
#  'vu-0415533-1',
#  'fluticasone',
#  'topotecan',
#  'flucloxacillin',
#  'alpha-estradiol',
#  'amisulpride',
#  'iohexol',
#  'as-601245',
#  'st-019386',
#  'bromocriptine',
#  'tribenoside',
#  'brd-a60386802',
#  'vincristine',
#  'budesonide',
#  'nitrarine',
#  'brd-a60784279',
#  'gliclazide',
#  'brd-a61189834',
#  'benserazide',
#  'aflatoxin-b1',
#  'tanespimycin',
#  'eliprodil',
#  'n-formylmethionylalanine',
#  'apramycin',
#  'brd-a61599461',
#  'emf-sumo1-6',
#  'metolazone',
#  'brd-a61825514',
#  'tremulacin',
#  ...]

# %%
drkg_names = [name.lower() for name in all_names]

# %%
drkg_names
# Out:
# ['lepirudin',
#  'hirudin variant-1',
#  'lepirudin recombinant',
#  'db00001',
#  'cetuximab',
#  'db00002',
#  'dornase alfa',
#  'deoxyribonuclease (human clone 18-1 protein moiety)',
#  'dornase alfa, recombinant',
#  'dornase alpha',
#  'recombinant deoxyribonuclease (dnase)',
#  'db00003',
#  'denileukin diftitox',
#  'denileukin',
#  'interleukin-2/diptheria toxin fusion protein',
#  'db00004',
#  'etanercept',
#  'etanercept-szzs',
#  'etanercept-ykro',
#  'recombinant human tnf',
#  'rhu tnfr:fc',
#  'rhu-tnfr:fc',
#  'tnfr-immunoadhesin',
#  'db00005',
#  'peginterferon alfa-2a',
#  'peg-ifn alfa-2a',
#  'peg-interferon alfa-2a',
#  'pegylated interfeaon alfa-2a',
#  'pegylated interferon alfa-2a',
#  'pegylated interferon alpha-2a',
#  'pegylated-interferon alfa 2a',
#  'db00008',
#  'alteplase',
#  'alteplase (genetical recombination)',
#  'alteplase, recombinant',
#  'alteplase,recombinant',
#  'plasminogen activator (human tissue-type protein moiety)',
#  'rt-pa',
#  't-pa',
#  't-plasminogen activator',
#  'tissue plasminogen activator',
#  'tissue plasminogen activator alteplase',
#  'tissue plasminogen activator, recombinant',
#  'tpa',
#  'db00009',
#  'sermorelin',
#  'db00010',
#  'interferon alfa-n1',
#  'interferon alpha-n1 (ins)',
#  'db00011',
#  'darbepoetin alfa',
#  'darbepoetin',
#  'darbepoetin alfa,recombinant',
#  'db00012',
#  'urokinase',
#  'kinase (enzyme-activating), uro-urokinase',
#  'tcuk',
#  'tissue culture urokinase',
#  'two-chain urokinase',
#  'db00013',
#  'reteplase',
#  'human t-pa (residues 1-3 and 176-527)',
#  'reteplase, recombinant',
#  'reteplase,recombinant',
#  'db00015',
#  'erythropoietin',
#  'e.p.o.',
#  'epoetin alfa',
#  'epoetin alfa rdna',
#  'epoetin alfa-epbx',
#  'epoetin alfa, recombinant',
#  'epoetin beta',
#  'epoetin beta rdna',
#  'epoetin epsilon',
#  'epoetin gamma',
#  'epoetin gamma rdna',
#  'epoetin kappa',
#  'epoetin omega',
#  'epoetin theta',
#  'epoetin zeta',
#  'erythropoiesis stimulating factor',
#  'erythropoietin (human, recombinant)',
#  'erythropoietin (recombinant human)',
#  'esf',
#  'sh-polypeptide-72',
#  'db00016',
#  'salmon calcitonin',
#  'calcitonin (salmon synthetic)',
#  'calcitonin salmon',
#  'calcitonin salmon recombinant',
#  'calcitonin-salmon',
#  'calcitonin, salmon',
#  'recombinant salmon calcitonin',
#  'db00017',
#  'interferon alfa-n3',
#  'db00018',
#  'pegfilgrastim',
#  'granulocyte colony-stimulating factor pegfilgrastim',
#  'peg-filgrastim',
#  'pegfilgrastim-bmez',
#  'pegfilgrastim-cbqv',
#  'pegfilgrastim-jmdb',
#  'db00019',
#  'sargramostim',
#  'recombinant human granulocyte-macrophage colony stimulating factor',
#  'rgm-csf',
#  'rhu gm-csf',
#  'db00020',
#  'peginterferon alfa-2b',
#  'db00022',
#  'asparaginase escherichia coli',
#  'asparaginase',
#  'asparaginase (e. coli)',
#  'colaspase',
#  'escherichia coli l-asparaginase',
#  'l-asparaginase',
#  'l-asparagine amidohydrolase',
#  'db00023',
#  'thyrotropin alfa',
#  'recombinant human thyroid stimulating hormone',
#  'recombinant thyrotropin alfa',
#  'rhtsh',
#  'rtsh',
#  'thyrotropin alpha',
#  'db00024',
#  'antihemophilic factor, human recombinant',
#  'antihemophilic factor (recombinant)',
#  'antihemophilic factor recombinant',
#  'antihemophilic factor, recombinant',
#  'factor viii (rdna)',
#  'factor viii (recombinant)',
#  'factor viii recombin',
#  'factor viii, recombinant',
#  'human factor viii (recombinant)',
#  'human factor viii recombinant',
#  'octocog alfa',
#  'rahf',
#  'recombinant antihemophilic factor viii',
#  'db00025',
#  'anakinra',
#  'il-1ra',
#  'interleukin-1 receptor antagonist anakinra',
#  'db00026',
#  'human immunoglobulin g',
#  'human igg',
#  'human normal immunoglobulin',
#  'immune globulin (human)',
#  'immune globulin human',
#  'immunoglobulin (human)',
#  'immunoglobulin g (human)',
#  'immunoglobulin g, human',
#  'ivig',
#  'db00028',
#  'anistreplase',
#  'anisoylated plasminogen streptokinase activator complex',
#  'apsac',
#  'db00029',
#  'insulin human',
#  'high molecular weight insulin human',
#  'human insulin',
#  'human insulin (rdna)',
#  'insulin (human)',
#  'insulin human [rdna origin]',
#  'insulin human regular',
#  'insulin human regular (rdna)',
#  'insulin human, rdna origin',
#  'insulin recombinant human',
#  'insulin recombinant purified human',
#  'insulin regular',
#  'insulin, human',
#  'regular insulin, human',
#  'db00030',
#  'tenecteplase',
#  'tnk-tpa',
#  'db00031',
#  'menotropins',
#  'human menopausal gonadotrophin',
#  'menotrophin',
#  'menotropin',
#  'menotropins (fsh;lh)',
#  'db00032',
#  'interferon gamma-1b',
#  'ifn-gamma 1b',
#  'ifn-gamma-1b',
#  'interferon gamma 1-b',
#  'interferon gamma-1b, recombinant',
#  'interferon gamma-2a',
#  'db00033',
#  'interferon alfa-2a, recombinant',
#  'interferon alfa-2a',
#  'interferon alfa-2a (recombinant)',
#  'interferon alfa-2a,recombinant',
#  'interferon alpha-2a',
#  'interferon-alfa-2a',
#  'recombinant human interferon alfa-2a',
#  'recombinant human interferon-alfa-2a',
#  'rifn-alpha-2a',
#  'sh-polypeptide-46',
#  'db00034',
#  'coagulation factor viia recombinant human',
#  'coagulation factor viia',
#  'coagulation factor viia (recombinant)',
#  'eptacog alfa',
#  'eptacog alfa (activated)',
#  'rfviia',
#  'db00036',
#  'oprelvekin',
#  'il-11',
#  'interleukin 11',
#  'interleukin-11',
#  'recombinant interleukin-11',
#  'db00038',
#  'palifermin',
#  '24-163 fibroblast growth factor 7 (human)',
#  'db00039',
#  'glucagon',
#  'glucagon (recombinant dna origin)',
#  'glucagon recombinant',
#  'glucagon, human',
#  'glucagon, porcine',
#  'glucagone',
#  'db00040',
#  'aldesleukin',
#  '125-l-serine-2-133-interleukin 2 (human reduced)',
#  'interleukin-2 aldesleukin',
#  'interleukin-2(2-133),125-ser',
#  'recombinant interleukin-2 human',
#  'db00041',
#  'botulinum toxin type b',
#  'botulin b',
#  'botulinum b toxin',
#  'botulinum neurotoxin type b precursor',
#  'btx-b',
#  'rimabotulinumtoxinb',
#  'db00042',
#  'omalizumab',
#  'db00043',
#  'lutropin alfa',
#  'lutropin alpha',
#  'db00044',
#  'lyme disease vaccine (recombinant ospa)',
#  'lipoprotein ospa antigen recombinant',
#  'lipoprotein outer surface a borrelia burgdorferi antigen',
#  'ospa lipoprotein',
#  'db00045',
#  'insulin lispro',
#  'insulin lispro (genetical recombination)',
#  'insulin lispro (rdna origin)',
#  'insulin lispro protamine',
#  'insulin lispro protamine recombinant',
#  'insulin lispro recombinant',
#  'insulin,lispro,human/rdna',
#  'insulin,lispro,protamine/rdna',
#  'db00046',
#  'insulin glargine',
#  'insulin glargine (rdna origin)',
#  'insulin glargine recombinant',
#  'db00047',
#  'collagenase clostridium histolyticum',
#  'clostridium histolyticum enzymes',
#  'collagenase',
#  'db00048',
#  'rasburicase',
#  'urate oxidase',
#  'db00049',
#  'adalimumab',
#  'adalimumab (genetical recombination)',
#  'adalimumab-adaz',
#  'adalimumab-adbm',
#  'adalimumab-afzb',
#  'adalimumab-atto',
#  'adalimumab-bwwd',
#  'db00051',
#  'somatotropin',
#  'growth hormone',
#  'growth hormone (human)',
#  'hgh',
#  'human growth hormone',
#  'recombinant human growth hormone',
#  'rhgh',
#  'somatotropin (human)',
#  'somatotropin human',
#  'somatotropin human growth hormone',
#  'somatropin',
#  'somatropin (rdna origin)',
#  'somatropin (recombinant dna origin)',
#  'somatropin [rdna origin]',
#  'somatropin recombinant',
#  'somatropin(recombinant dna origin)',
#  'db00052',
#  'imiglucerase',
#  'db00053',
#  'abciximab',
#  'abciximab (genetical recombination)',
#  'c7e3',
#  'db00054',
#  'drotrecogin alfa',
#  'activated protein c',
#  'blood coagulation factor xiv (human)',
#  'drotrecogin alfa (activated)',
#  'drotrecogin alfa (activated), lyophilized',
#  'drotrecogin alfa activated',
#  'drotrecogin alfa, activated',
#  'drotrecogin-alfa',
#  'recombinant human activated protein c (rh-apc)',
#  'db00055',
#  'gemtuzumab ozogamicin',
#  'db00056',
#  'indium in-111 satumomab pendetide',
#  'indium (111in) satumomab pendetide',
#  'indium in 111 satumomab pendetide',
#  'indium-111 satumomab pendetide',
#  'db00057',
#  'alpha-1-proteinase inhibitor',
#  'alfa 1-proteinase inhibitor (human)',
#  'alfa1 antitrypsin',
#  'alpha 1-antitrypsin',
#  'alpha 1-proteinase inhibitor',
#  'alpha 1-proteinase inhibitor (human)',
#  'alpha 1-proteinase inhibitor, human',
#  'alpha-1 protease inhibitor',
#  'alpha-1 proteinase inhibitor (human)',
#  'alpha-1-antiproteinase',
#  'alpha-1-antitrypsin',
#  'alpha-1-proteinase inhibitor (human)',
#  'alpha-1-proteinase inhibitor human',
#  'alpha-1-proteinase inhibitor, human',
#  'alpha-1-proteinase inhibitor,human',
#  'alpha1-proteinase inhibitor',
#  'alpha1-proteinase inhibitor (human)',
#  'alpha1-proteinase inhibitor human',
#  'api',
#  'db00058',
#  'pegaspargase',
#  'peg-asparaginase',
#  'peg/l-asparaginase',
#  'db00059',
#  'interferon beta-1a',
#  'interferon beta 1-a',
#  'interferon beta 1a',
#  'interferon beta-1a (recombinant human)',
#  'interferon beta-1a,recombinant',
#  'interferon-beta-1a',
#  'db00060',
#  'pegademase',
#  '(monomethoxypolyethylene glycol succinimidyl) 11-17-adenosine deaminase',
#  'peg-adenosine deaminase',
#  'pegada',
#  'pegademase bovine',
#  'db00061',
#  'albumin human',
#  'albumin (human)',
#  'albumin, blood',
#  'albumin, human',
#  'albumin, human-kjda',
#  'human albumin',
#  'human serum albumin',
#  'serum albumin',
#  'db00062',
#  'eptifibatide',
#  'integrelin',
#  'intrifiban',
#  'db00063',
#  'infliximab',
#  'infliximab (genetical recombination)',
#  'infliximab-abda',
#  'infliximab-axxq',
#  'infliximab-dyyb',
#  'infliximab-qbtx',
#  'db00065',
#  'follitropin',
#  'follicle stimulating hormone',
#  'follitrophin alfa',
#  'follitrophin alpha',
#  'follitrophin beta',
#  'follitropin alfa',
#  'follitropin alfa/beta',
#  'follitropin alpha',
#  'follitropin beta',
#  'follitropin delta',
#  'follitropin gamma',
#  'follotropin recombinant',
#  'fsh',
#  'fsh alpha',
#  'fsh-a',
#  'fsh-b',
#  'fsh-beta',
#  'recombinant human follicle stimulating hormone beta',
#  'recombinant human follicle-stimulating hormone (r-hfsh)',
#  'rfsh-alpha',
#  'db00066',
#  'interferon beta-1b',
#  'interferon beta 1b (recombinant)',
#  'interferon beta-1b,recombinant',
#  'interferon-beta-1b',
#  'recombinant interferon beta-1b',
#  'db00068',
#  'interferon alfacon-1',
#  'ifn alfacon-1',
#  'ifn-con1',
#  'db00069',
#  'hyaluronidase (ovine)',
#  'hyaluronidase (glycoprotein, sheep testis isoenzyme)',
#  'hyaluronidase (sheep testis isoenzyme)',
#  'hyaluronidase, ovine',
#  'ovine hyaluronidase',
#  'db00070',
#  'insulin pork',
#  'insulin (pork)',
#  'insulin porcine',
#  'insulin purified porcine',
#  'insulin purified pork',
#  'insulin, porcine',
#  'insulin, regular, pork',
#  'porcine insulin',
#  'db00071',
#  'trastuzumab',
#  'rhumab her2',
#  'trastuzumab-anns',
#  'trastuzumab-dkst',
#  'trastuzumab-dttb',
#  'trastuzumab-pkrb',
#  'trastuzumab-qyyp',
#  'db00072',
#  'rituximab',
#  'rituximab-abbs',
#  'rituximab-pvvr',
#  'db00073',
#  'basiliximab',
#  'db00074',
#  'muromonab',
#  'anti-cd3',
#  'muromonab-cd3',
#  'db00075',
#  'digoxin immune fab (ovine)',
#  'digitalis antitoxin',
#  'digoxin immune fab, ovine',
#  'digoxin-specific antibody fragments',
#  'ovine digoxin immune fab',
#  'db00076',
#  'ibritumomab tiuxetan',
#  'ibritumomab',
#  'mab murine (igg1) anti p19437 (cd20_mouse)',
#  'db00078',
#  'tositumomab',
#  'db00081',
#  'pegvisomant',
#  'db00082',
#  'botulinum toxin type a',
#  'abobotulinumtoxina',
#  'botulinum a neurotoxin',
#  'botulinum toxin a',
#  'btx-a',
#  'evabotulinumtoxina',
#  'incobotulinumtoxina',
#  'onabotulinumtoxina',
#  'prabotulinumtoxin a',
#  'db00083',
#  'pancrelipase',
#  'pancrealipase',
#  'pancreatic extract pancrelipase',
#  'pancreatic protease',
#  'pancreatin',
#  'pancrelipase (amylase;lipase;protease)',
#  'db00085',
#  'streptokinase',
#  'streptococcal fibrinolysin',
#  'db00086',
#  'alemtuzumab',
#  'db00087',
#  'alglucerase',
#  'db00088',
#  'capromab pendetide',
#  '(111in)-capromab pendetide',
#  'indium (111in) capromab pendetide',
#  'indium 111 capromab pendetide',
#  'indium in 111 capromab pendetide',
#  'db00089',
#  'laronidase',
#  'alpha-l-idosiduronase',
#  'human recombinant alpha-l-iduronidase',
#  'laronidase (genetical recombination)',
#  'db00090',
#  'alefacept',
#  'db00092',
#  'urofollitropin',
#  'follitropin human',
#  'urofollitrophin',
#  'db00094',
#  'efalizumab',
#  'anti-cd11a',
#  'anticd11 alpha',
#  'db00095',
#  'choriogonadotropin alfa',
#  'choriogonadotropin alpha',
#  'chorionic gonadotropin (recombinant)',
#  'db00097',
#  'antithymocyte immunoglobulin (rabbit)',
#  'anti-human thymocyte immunoglobulin, rabbit',
#  'anti-t-lymphocyte immune globulin, rabbit',
#  'anti-thymocyte globulin (rabbit)',
#  'anti-thymocyte globulin rabbit',
#  'antithymocyte immunoglobulin',
#  'lapine t-lymphocyte immune globulin',
#  'rabbit anti-human thymocyte globulin',
#  'rabbit anti-human thymocyte globulin (ratg)',
#  'rabbit anti-human thymocyte immunoglobulin',
#  'rabbit anti-thymocyte immunoglobulin',
#  'rabbit antithymocyte globulin',
#  'rabbit atg',
#  'ratg',
#  'thymoglobulin',
#  'thymoglobuline',
#  'db00098',
#  'filgrastim',
#  'filgrastim-aafi',
#  'filgrastim-sndz',
#  'g-csf',
#  'granulocyte colony stimulating factor',
#  'tbo-filgrastim',
#  'db00099',
#  'coagulation factor ix (recombinant)',
#  'coagulation factor ix recombinant human',
#  'factor ix (recombinant)',
#  'nonacog alfa',
#  'nonacog gamma',
#  'recombinant factor ix',
#  'db00100',
#  'becaplermin',
#  'pdgf-2',
#  'pdgf-bb',
#  'pdgfb',
#  'platelet-derived growth factor bb, recombinant',
#  'platelet-derived growth factor beta polypeptide',
#  'recombinant platelet-derived growth factor bb',
#  'rhpdgf-bb',
#  'rpdgf-bb',
#  'sh-polypeptide-59',
#  'db00102',
#  'agalsidase beta',
#  'agalsidase alfa',
#  'alpha-galactosidase a',
#  'db00103',
#  'interferon alfa-2b',
#  'interferon alfa-2b, recombinant',
#  'interferon alpha-2b',
#  'intron (interferon alpha2b)',
#  'intron a',
#  'intron a (interferon alpha2b)',
#  'r-inf-alpha',
#  'rifn-alpha-2b',
#  'db00105',
#  'oxytocin',
#  'db00107',
#  'natalizumab',
#  'anti-alpha4 integrin',
#  'anti-vla4',
#  'db00108',
#  'enfuvirtide',
#  'db00109',
#  'palivizumab',
#  'db00110',
#  'daclizumab',
#  'dacliximab',
#  'daclizumab beta',
#  'db00111',
#  'bevacizumab',
#  'anti-vegf humanized monoclonal antibody',
#  'anti-vegf monoclonal antibody',
#  'bevacizumab-awwb',
#  'rhumab-vegf',
#  'db00112',
#  'technetium tc-99m arcitumomab',
#  'arcitumomab technetium-99m',
#  'technetium (99mtc) arcitumomab',
#  'technetium tc 99m arcitumomab',
#  'technetium-99m arcitumomab',
#  'db00113',
#  'eculizumab',
#  'db01257',
#  'panitumumab',
#  'abx-egf',
#  'db01269',
#  'ranibizumab',
#  'rhufab v2',
#  'db01270',
#  'idursulfase',
#  'alpha-l-iduronate sulfate sulfatase',
#  'iduronate 2-sulfatase',
#  'db01271',
#  'alglucosidase alfa',
#  'acid maltase',
#  'acid-alpha glucosidase',
#  'aglucosidase alfa',
#  'aglucosidase alpha',
#  'alpha-1,4-glucosidase',
#  'alpha-glucosidase',
#  'lysosomal alpha-glucosidase',
#  'db01272',
#  'exenatide',
#  'exenatide synthetic',
#  'exendin 4',
#  'exendin-4',
#  'synthetic exendin-4',
#  'db01276',
#  'mecasermin',
#  'human somatomedin c',
#  'mecasermin recombinant',
#  'mechano growth factor',
#  'db01277',
#  'galsulfase',
#  'arylsulfatase b galsulfase',
#  'galsulfase (genetical recombination)',
#  'db01279',
#  'abatacept',
#  'abatacept recombinant',
#  'db01281',
#  'corticotropin',
#  'acth',
#  'adrenocorticotrophin',
#  'adrenocorticotropic hormone',
#  'corticotrophin',
#  'cortigel',
#  'h.p. acthar gel',
#  'db01285',
#  'insulin aspart',
#  'aspart',
#  'aspart insulin',
#  'b28-aspart-insulin',
#  'insulin aspart protamine',
#  'insulin aspart protamine recombinant',
#  'insulin aspart recombinant',
#  'insulin x14',
#  'insulin, aspart protamine, human',
#  'insulin, aspart, human',
#  'insulin,aspart protamine',
#  'db01306',
#  'insulin detemir',
#  'detemir',
#  'insulin detemir recombinant',
#  'insulin,detemir,human',
#  'db01307',
#  'insulin glulisine',
#  'insulin glulisine (recombinant dna origin)',
#  'insulin glulisine recombinant',
#  'db01309',
#  'ephedra sinica root',
#  'cao ma huang root',
#  'chinese ephedra root (ephedra sinica)',
#  'chinese jointfir',
#  'ephedra',
#  'ephedra ma-huang root',
#  'ephedra root (ephedra sinica)',
#  'ephedrae radix',
#  'hemp yellow root',
#  'ma huang gen (ephedra sinica)',
#  'mahuanggen (ephedra sinica)',
#  'db01363',
#  'ginkgo biloba',
#  'common ginkgo leaf',
#  'ginkgo',
#  'ginkgo biloba extract',
#  'ginkgo biloba leaf',
#  'ginkgo biloba leaf dry extract',
#  'ginkgo biloba leaf tincture',
#  'ginkgo extract',
#  'ginkgo folium',
#  'ginkgo leaf',
#  'ginkgo macrophylla leaf',
#  'maidenhair extract',
#  'maidenhair tree leaf',
#  'pterophyllus salisburiensis leaf',
#  'salisburia adiantifolia leaf',
#  'salisburia biloba leaf',
#  'salisburia ginkgo leaf',
#  'salisburia macrophylla leaf',
#  'tanakan',
#  'yinxingye',
#  'db01381',
#  'hemin',
#  'chloro(protoporphyrinato)iron(iii)',
#  'protohemin',
#  'db03404',
#  'pegaptanib',
#  'eye 001',
#  'nx 1838',
#  'nx1838',
#  'pegaptanib octasodium',
#  'pegaptanib sodium',
#  'db04895',
#  'lucinactant',
#  'ati-02',
#  'kl4-surfactant',
#  'db04897',
#  'nesiritide',
#  'bnp',
#  'bnp-32',
#  'brain natriuretic peptide 32',
#  'human brain natriuretic factor-32',
#  'nesiritide recombinant',
#  'db04899',
#  'thymalfasin',
#  'thymosin alpha1 (human)',
#  'db04900',
#  'galiximab',
#  'anti-cd80 monoclonal antibody',
#  'db04901',
#  'sitimagene ceradenovec',
#  'db04907',
#  'g17dt',
#  'antigastrin 17',
#  'gastrin 17 immunogen',
#  'gastrin 17 vaccine',
#  'db04914',
#  'alfimeprase',
#  'db04919',
#  'desmoteplase',
#  'dspa desmoteplase',
#  'rdspa alpha 1',
#  'salivary plasminogen activator alpha 1, desmodus rotundus',
#  'db04925',
#  'defibrotide',
#  'defibrotide free acid',
#  'defibrotide free acid (porcine mucosa)',
#  'defibrotide free acid (porcine)',
#  'db04932',
#  'pexelizumab',
#  '5g1.1-sc',
#  'h5g1.1-scfv',
#  'db04949',
#  'ranpirnase',
#  'db04950',
#  'afelimomab',
#  'db04956',
#  'epratuzumab',
#  'immu-hll2',
#  'db04958',
#  'verpasep caltespen',
#  'bcg65-e7',
#  'heat-shock protein hsp 65 (mycobacterium bcg) fusion protein with transcription factor e7 (human papillomavirus 16)',
#  'hpv 16 e7/hsp65 vaccine',
#  'hpv e7 peptide epitope vaccine',
#  'hspe7',
#  'db04959',
#  'bectumomab',
#  'db04962',
#  'oregovomab',
#  'monoclonal antibody b43.13',
#  'oregovamab',
#  'db04964',
#  'lerafaon',
#  'db04973',
#  'tigapotide',
#  'db04985',
#  'ign311',
#  'db04988',
#  'adecatumumab',
#  'db05006',
#  'abaloparatide',
#  'db05084',
#  'labetuzumab',
#  'hmn-14',
#  'mab hmn14',
#  'monoclonal antibody hmn-14',
#  'db05097',
#  'ancrod',
#  'db05099',
#  'matuzumab',
#  'db05101',
#  'vir201',
#  'db05110',
#  'fontolizumab',
#  'db05111',
#  '1d09c3',
#  'db05121',
#  'bavituximab',
#  'db05136',
#  'cr002',
#  'db05139',
#  'pev3a',
#  'db05144',
#  'cmlvax100',
#  'db05164',
#  'egaptivon pegol',
#  'db05202',
#  'rozrolimupab',
#  'recombinant human antigen-specific polyclonal antibody (pab) against rhd antigen expressed in chinese hamster ovary cells',
#  'db05209',
#  'pn0621',
#  'db05218',
#  'kb001',
#  'db05222',
#  'fibrinolysin',
#  'bovine fibrinolysin',
#  'bovine plasmin',
#  'fibrinolysin (human)',
#  'fibrinolysin, human',
#  'plasmin (bos taurus)',
#  'plasmin (bovine)',
#  'plasmin bovine',
#  'db05254',
#  'interferon alfa',
#  'huifn-alpha-le',
#  'ifn-alpha',
#  'natural alpha interferon',
#  'db05258',
#  'glatiramer',
#  '(t,g)-a-l',
#  'cop 1',
#  'cop-1',
#  'copolymer i (synthetic peptide)',
#  'copolymer-1',
#  'db05259',
#  'hepatitis b immune globulin',
#  'hbig',
#  'hepatitis b immune globulin (human)',
#  'hepatitis b immune globulin human',
#  'hepatitis b immunoglobulin (human)',
#  'human hepatitis b immunoglobulin',
#  'human hepatitis b virus immune globulin',
#  'human hepatitis-b immunoglobulin',
#  'db05276',
#  'keyhole limpet hemocyanin',
#  'db05299',
#  'girentuximab',
#  'db05304',
#  'cintredekin besudotox',
#  'db05305',
#  'alferminogene tadenovec',
#  'ad5fgf-4',
#  'db05306',
#  'ecallantide',
#  'db05311',
#  'oportuzumab monatox',
#  'db05319',
#  'peg-uricase',
#  'db05321',
#  'ingn 225',
#  'db05325',
#  'romiplostim',
#  'db05332',
#  'obiltoxaximab',
#  'db05336',
#  'sot-107',
#  'db05337',
#  'regramostim',
#  'colony-stimulating factor 2 (human clone pcsf-1 protein moiety reduced), glycoform gmc 89-107',
#  'gm-csf',
#  'rhgm-csf',
#  'db05386',
#  'albinterferon alfa-2b',
#  'alb-ifn',
#  'albinterferon',
#  'albuferon alpha',
#  'albumin-interferon alpha',
#  'db05396',
#  'xtl-001',
#  'db05405',
#  'cat-213',
#  'db05429',
#  'nav 1800',
#  'rigscan cr',
#  'rigscan cr49',
#  'db05437',
#  'briakinumab',
#  'db05459',
#  'sgn-30',
#  'db05471',
#  'recombinant alpha 1-antitrypsin',
#  'db05481',
#  'otelixizumab',
#  'db05496',
#  'cpg 10101',
#  'db05530',
#  'amg 108',
#  'db05545',
#  'iratumumab',
#  'db05550',
#  'enokizumab',
#  '7f3com-2h2',
#  '7f3com2h2',
#  'db05555',
#  'ramucirumab',
#  'db05578',
#  'farletuzumab',
#  'db05595',
#  'veltuzumab',
#  'db05656',
#  'ep-2104r',
#  'db05675',
#  'ustekinumab',
#  'stelera',
#  'db05679',
#  'fx06',
#  'db05685',
#  'maxy-g34',
#  'db05718',
#  'cyt006-angqb',
#  'db05739',
#  'cyt007-tnfqb',
#  'db05758',
#  'lll-3348',
#  'db05771',
#  'trastuzumab emtansine',
#  'ado-trastuzumab',
#  'ado-trastuzumab emtansine',
#  't-dm1',
#  'trastuzumab-dm1',
#  'trastuzumab-mcc-dm1',
#  'db05773',
#  'thrombomodulin alfa',
#  'thrombomodulin (human 498-amino acid fragment)',
#  'db05777',
#  'lm-609',
#  'db05787',
#  'pro-542',
#  'db05793',
#  'serelaxin',
#  'human relaxin 2 (relaxin h2)',
#  'human relaxin recombinant',
#  'recombinant human relaxin',
#  'db05794',
#  'tnx-901',
#  'db05797',
#  'gem-231',
#  'db05798',
#  'nbi-6024',
#  'db05819',
#  'parathyroid hormone',
#  'parathormone',
#  'parathormone (human recombinant)',
#  'parathyrin',
#  'parathyroid hormone (1-84) human recombinant',
#  'parathyroid hormone (rdna)',
#  'pth',
#  'pth(1-84)',
#  'rhpth',
#  'rhpth(1-84)',
#  'rpth',
#  'rpth(1-84)',
#  'db05829',
#  'humanized smart anti-il-12 antibody',
#  'db05848',
#  'peginterferon alfacon-1',
#  'peg inf alfacon-1',
#  'peg-alfacon',
#  'peg-infergen',
#  'peg-interferon alfacon-1',
#  'pegylated interferon alfacon-1',
#  'db05860',
#  '99mtc-14 f7 mab',
#  'db05867',
#  'ame-527',
#  'db05879',
#  'abx-pth',
#  'db05883',
#  'inotuzumab ozogamicin',
#  'db05889',
#  'ri 624',
#  'db05892',
#  'hgs-tr2j',
#  'db05895',
#  'ccr5 mab',
#  'db05906',
#  'myo-029',
#  'db05915',
#  'ct-011',
#  'db05916',
#  'leronlimab',
#  'db05941',
#  'gi-5005',
#  'db05942',
#  'mdx-1303',
#  'db05945',
#  'glembatumumab vedotin',
#  'db05996',
#  'eteplirsen',
#  '(p-deoxy-p-(dimethylamino)](2&apos;,3&apos;-dideoxy-2&apos;,3&apos;-imino-2&apos;,3&apos;-seco)(2&apos;a--&gt;5&apos;)(c-m5u-c-c-a-a-c-a-m5u-c-a-a-g-g-a-a-g-a-m5u-g-g-c-a-m5u-m5u-m5u-c-m5u-a-g),5&apos;-(p-(4-((2-(2-(2-hydroxyethoxy)ethoxy)ethoxy)carbonyl)-1-piperazinyl)-n,n-dimethylphosphonamidate) rna',
#  'db06014',
#  'glycopeg-gcsf',
#  'db06022',
#  'olaratumab',
#  'db06043',
#  'iph 2101',
#  'db06049',
#  'tb-402',
#  'db06050',
#  'caplacizumab',
#  'caplacizumab-yhdp',
#  'db06081',
#  'imc-1c11',
#  'db06101',
#  'eldelumab',
#  'db06116',
#  'lumiliximab',
#  'gomiliximab',
#  'db06162',
#  'canakinumab',
#  'db06168',
#  'paclitaxel trevatide',
#  ...]

# %%
len(set(drkg_names).intersection(set(l1000_names)))
# Out:
# 1730

# %%
len(l1000_names)
# Out:
# 53553

# %% [markdown]
# ## Comparing fingerprints with Genevieve's code

# %%
drugbank_smiles
# Out:
# array(['CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@@H]1CCCN1C(=O)[C@H](N)CC1=CC=CC=C1)C(=O)N1CCC[C@H]1C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@@H](CC(C)C)C(O)=O',
#        'CCNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@H](CC(C)C)NC(=O)[C@@H](CC(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CC1=CNC2=C1C=CC=C2)NC(=O)[C@H](CC1=CNC=N1)NC(=O)[C@@H]1CCC(=O)N1',
#        'CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H](CC1=CC=C(O)C=C1)NC(=O)[C@H](CO)NC(=O)[C@H](CC1=CNC2=CC=CC=C12)NC(=O)[C@H](CC1=CN=CN1)NC(=O)[C@@H]1CCC(=O)N1)C(=O)N[C@@H](CCCN=C(N)N)C(=O)N1CCC[C@H]1C(=O)NNC(N)=O',
#        ..., 'CC(C)N(CC[C@H](C1=CC=CC=C1)C1=CC(CO)=CC=C1O)C(C)C',
#        '[Na+].CCOC1=CC=C(NC2=CC=C(C=C2)C(=C2\\C=C/C(/C=C2C)=[N+](/CC)CC2=CC(=CC=C2)S([O-])(=O)=O)\\C2=C(C)C=C(C=C2)N(CC)CC2=CC(=CC=C2)S([O-])(=O)=O)C=C1',
#        '[Fe+3].CC1=C([O-])C(=O)C=CO1.CC1=C([O-])C(=O)C=CO1.CC1=C([O-])C(=O)C=CO1'],
#       dtype=object)

# %%
l1000_smiles
# Out:
# array(['-666', 'CC1CS(=O)(=O)CCN1N=Cc1ccc(o1)[N+]([O-])=O',
#        'NC(Cc1c[nH]c2cccc(O)c12)C(O)=O', ...,
#        'CCCc1cc2c(ncnc2s1)N1CCN(CC1)C1=NCC(C)(C)S1',
#        'COc1cc(O)c2c(c1)oc(cc2=O)-c1ccc(OC)c(c1)-c1c(O)cc(O)c2c1oc(cc2=O)-c1ccc(O)cc1',
#        'O=C1c2ccccc2-c2nc3nonc3nc12'], dtype=object)

# %%
len(drugbank_smiles)
# Out:
# 8830

# %%
len(l1000_smiles)
# Out:
# 21213

# %%
molecules_db = [Chem.MolFromSmiles(smile) for smile in drugbank_smiles]
molecules_l1000 = [Chem.MolFromSmiles(smile) for smile in l1000_smiles]
# Out:
# RDKit ERROR: [14:37:59] Explicit valence for atom # 2 O, 3, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 0 N, 4, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 0 N, 4, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 0 N, 4, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 13 Cl, 5, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 14 N, 5, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 19 O, 3, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 2 O, 3, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 6 N, 4, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 11 N, 4, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 0 O, 3, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 6 Be, 4, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 3 N, 4, is greater than permitted
# RDKit ERROR: [14:37:59] Explicit valence for atom # 4 F, 2, is greater than permitted
# RDKit ERROR: [14:38:00] SMILES Parse Error: syntax error while parsing: CCN1CCC(CC1)NC2=CC=C(C=C2)NC(=O)/C3=C(/C4=CC(=CC=C4)F)\C5=NC=C(N5)C
# RDKit ERROR: [14:38:00] SMILES Parse Error: Failed parsing SMILES 'CCN1CCC(CC1)NC2=CC=C(C=C2)NC(=O)/C3=C(/C4=CC(=CC=C4)F)\C5=NC=C(N5)C' for input: 'CCN1CCC(CC1)NC2=CC=C(C=C2)NC(=O)/C3=C(/C4=CC(=CC=C4)F)\C5=NC=C(N5)C'
# RDKit ERROR: [14:38:00] SMILES Parse Error: syntax error while parsing: C[C@H](C/C=C/S(=O)(=O)C(C)(C)C)C1=CC[C@@H][C@@]1(CCC/C2=C\C=C/3\C[C@H](C[C@@H](C3=C)O)O)C
# RDKit ERROR: [14:38:00] SMILES Parse Error: Failed parsing SMILES 'C[C@H](C/C=C/S(=O)(=O)C(C)(C)C)C1=CC[C@@H][C@@]1(CCC/C2=C\C=C/3\C[C@H](C[C@@H](C3=C)O)O)C' for input: 'C[C@H](C/C=C/S(=O)(=O)C(C)(C)C)C1=CC[C@@H][C@@]1(CCC/C2=C\C=C/3\C[C@H](C[C@@H](C3=C)O)O)C'
# RDKit ERROR: [14:38:00] SMILES Parse Error: syntax error while parsing: CC=C(C2=C(/C1=C\C3=CC=NC=C3)C=CC(=C2)F)CC(=O)NCC4=CC=CC=C4.Cl
# RDKit ERROR: [14:38:00] SMILES Parse Error: Failed parsing SMILES 'CC=C(C2=C(/C1=C\C3=CC=NC=C3)C=CC(=C2)F)CC(=O)NCC4=CC=CC=C4.Cl' for input: 'CC=C(C2=C(/C1=C\C3=CC=NC=C3)C=CC(=C2)F)CC(=O)NCC4=CC=CC=C4.Cl'
# RDKit ERROR: [14:38:00] SMILES Parse Error: syntax error while parsing: CCN(C(=O)/C1=C/2\C[C@@H](NC3=C2C=CC(=C3)Cl)C(=O)O)C4=CC=CC=C4
# RDKit ERROR: [14:38:00] SMILES Parse Error: Failed parsing SMILES 'CCN(C(=O)/C1=C/2\C[C@@H](NC3=C2C=CC(=C3)Cl)C(=O)O)C4=CC=CC=C4' for input: 'CCN(C(=O)/C1=C/2\C[C@@H](NC3=C2C=CC(=C3)Cl)C(=O)O)C4=CC=CC=C4'
# RDKit ERROR: [14:38:00] Explicit valence for atom # 13 Be, 3, is greater than permitted
# RDKit ERROR: [14:38:00] SMILES Parse Error: syntax error while parsing: C[C@H](CCCC(C)C)[C@H]1CC[C@@H][C@@]1(CCC/C2=C\C=C/3\C[C@H](CCC3=C)O)C
# RDKit ERROR: [14:38:00] SMILES Parse Error: Failed parsing SMILES 'C[C@H](CCCC(C)C)[C@H]1CC[C@@H][C@@]1(CCC/C2=C\C=C/3\C[C@H](CCC3=C)O)C' for input: 'C[C@H](CCCC(C)C)[C@H]1CC[C@@H][C@@]1(CCC/C2=C\C=C/3\C[C@H](CCC3=C)O)C'
# RDKit ERROR: [14:38:01] SMILES Parse Error: syntax error while parsing: OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1
# RDKit ERROR: [14:38:01] SMILES Parse Error: Failed parsing SMILES 'OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1' for input: 'OC1=CC=CC(=C1)C-1=C2\CCC(=N2)\C(=C2/N\C(\C=C2)=C(/C2=N/C(/C=C2)=C(\C2=CC=C\-1N2)C1=CC(O)=CC=C1)C1=CC(O)=CC=C1)\C1=CC(O)=CC=C1'
# RDKit ERROR: [14:38:01] Explicit valence for atom # 0 N, 4, is greater than permitted
# RDKit ERROR: [14:38:01] SMILES Parse Error: syntax error while parsing: C[C@@H]1[C@H]([C@@H]([C@@H]([C@@H](O1)OCCC3C(C(CC(O3)(CC(CC(CCCC(CC(CC(=O)CC(=O)OC(C(/C=C/C=C/C=C/C=C/C=C/C=C/C=C2)C)C(C)CCC(CC(=O)C4=CC=C(C=C4)N)O)O)O)O)O)O)O)C(=O)O)O)N)O.C[C@@H]1[C@H]([C@@H]([C@@H]([C@@H](O1)OCCC3C(C(CC(O3)(CC(CC(CC(CC(CCCC(=O)CC(=O)OC(C(/C=C/C=C/C=C/C=C/C=C/C=C/C=C2)C)C(C)CCC(CC(=O)C4=CC=C(C=C4)N)O)O)O)O)O)O)O)C(=O)O)O)N)O
# RDKit ERROR: [14:38:01] SMILES Parse Error: Failed parsing SMILES 'C[C@@H]1[C@H]([C@@H]([C@@H]([C@@H](O1)OCCC3C(C(CC(O3)(CC(CC(CCCC(CC(CC(=O)CC(=O)OC(C(/C=C/C=C/C=C/C=C/C=C/C=C/C=C2)C)C(C)CCC(CC(=O)C4=CC=C(C=C4)N)O)O)O)O)O)O)O)C(=O)O)O)N)O.C[C@@H]1[C@H]([C@@H]([C@@H]([C@@H](O1)OCCC3C(C(CC(O3)(CC(CC(CC(CC(CCCC(=O)CC(=O)OC(C(/C=C/C=C/C=C/C=C/C=C/C=C/C=C2)C)C(C)CCC(CC(=O)C4=CC=C(C=C4)N)O)O)O)O)O)O)O)C(=O)O)O)N)O' for input: 'C[C@@H]1[C@H]([C@@H]([C@@H]([C@@H](O1)OCCC3C(C(CC(O3)(CC(CC(CCCC(CC(CC(=O)CC(=O)OC(C(/C=C/C=C/C=C/C=C/C=C/C=C/C=C2)C)C(C)CCC(CC(=O)C4=CC=C(C=C4)N)O)O)O)O)O)O)O)C(=O)O)O)N)O.C[C@@H]1[C@H]([C@@H]([C@@H]([C@@H](O1)OCCC3C(C(CC(O3)(CC(CC(CC(CC(CCCC(=O)CC(=O)OC(C(/C=C/C=C/C=C/C=C/C=C/C=C/C=C2)C)C(C)CCC(CC(=O)C4=CC=C(C=C4)N)O)O)O)O)O)O)O)C(=O)O)O)N)O'
# RDKit ERROR: [14:38:01] Explicit valence for atom # 0 Mg, 4, is greater than permitted
# RDKit ERROR: [14:38:01] SMILES Parse Error: syntax error while parsing: -666
# RDKit ERROR: [14:38:01] SMILES Parse Error: Failed parsing SMILES '-666' for input: '-666'
# RDKit ERROR: [14:38:08] SMILES Parse Error: syntax error while parsing: restricted
# RDKit ERROR: [14:38:08] SMILES Parse Error: Failed parsing SMILES 'restricted' for input: 'restricted'

# %%
print(len(drugbank_smiles), len(molecules_db))
print(len(l1000_smiles), len(molecules_l1000))
# Out:
# 8830 8830
# 21213 21213

# %%
# Remove None values
molecules_db = [mol for mol in molecules_db if mol is not None]
molecules_l1000 = [mol for mol in molecules_l1000 if mol is not None]

# %%
print(len(drugbank_smiles), len(molecules_db))
print(len(l1000_smiles), len(molecules_l1000))
# Out:
# 8830 8806
# 21213 21211

# %%
recomputed_smiles_db = [Chem.MolToSmiles(mol) for mol in molecules_db]
recomputed_smiles_l1000 = [Chem.MolToSmiles(mol) for mol in molecules_l1000]

# %%
len(set(recomputed_smiles_db).intersection(set(recomputed_smiles_l1000)))
# Out:
# 1574

# %%
hashstring_db = [rdMolHash.GenerateMoleculeHashString(mol) for mol in molecules_db]
hashstring_l1000 = [rdMolHash.GenerateMoleculeHashString(mol) for mol in molecules_l1000]
# Out:
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:53] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:54] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:55] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:55] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:55] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:55] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:55] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:55] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:55] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:55] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:55] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:55] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:55] Warning: atom with more than 1 ring-stereo atoms found.
# RDKit WARNING: [14:44:55] Warning: atom with more than 1 ring-stereo atoms found.

# %%
len(set(hashstring_db).intersection(set(hashstring_l1000)))
# Out:
# 1610
